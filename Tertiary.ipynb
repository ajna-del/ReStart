# %% [markdown]
# <a href="https://colab.research.google.com/github/ajna-del/ReStart/blob/master/Tertiary.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import os
from pydrive.auth import GoogleAuth
from pydrive.drive import GoogleDrive
from google.colab import auth
from oauth2client.client import GoogleCredentials
auth.authenticate_user()
gauth = GoogleAuth()
gauth.credentials = GoogleCredentials.get_application_default()
drive = GoogleDrive(gauth)
#for timing
# !pip install ipython-autotime
# %load_ext autotime

# N/D ~2520 images
# download = drive.CreateFile({'id': '1iLNy9L4gxfiKpvedeNRJpc6gktroqCwQ'})
# download.GetContentFile('ND.7z') # Save content of this file as a local file - images
# os.mkdir('/content/RenamedImages')
# !7z e ND.7z -o'/content/RenamedImages'


# N/C filtered images 
# download = drive.CreateFile({'id': '1C6iVZC4g_CSKKHQKnT-mJ4mEwHOEpb3x'}) #do i need this???
# download.GetContentFile('NC-filtered.7z') # Save content of this file as a local file - images
# os.mkdir('/content/RenamedImages')
# !7z e NC-filtered.7z -o'/content/RenamedImages'

# NCA filtered images 
# download = drive.CreateFile({'id': '1DkH6_NkjBhB7wtCWTXG6fhBImuC1nT_V'}) #do i need this???
# download.GetContentFile('NCA-filtered.7z') # Save content of this file as a local file - images
# os.mkdir('/content/RenamedImages')
# !7z e NCA-filtered.7z -o'/content/RenamedImages'


# NCA Cropped images 
download = drive.CreateFile({'id': '1j7_xIgFN04t06_XfVLHnioCawNo8XBDd'}) #do i need this???
download.GetContentFile('NCA-Cropped.7z') # Save content of this file as a local file - images
os.mkdir('/content/RenamedImages')
!7z e NCA-Cropped.7z -o'/content/RenamedImages'
# Out:
# <p style="color: red;">
# The default version of TensorFlow in Colab will soon switch to TensorFlow 2.x.<br>
# We recommend you <a href="https://www.tensorflow.org/guide/migrate" target="_blank">upgrade</a> now
# or ensure your notebook will continue to use TensorFlow 1.x via the <code>%tensorflow_version 1.x</code> magic:
# <a href="https://colab.research.google.com/notebooks/tensorflow_version.ipynb" target="_blank">more info</a>.</p>
# WARNING:tensorflow:
# The TensorFlow contrib module will not be included in TensorFlow 2.0.
# For more information, please see:
#   * https://github.com/tensorflow/community/blob/master/rfcs/20180907-contrib-sunset.md
#   * https://github.com/tensorflow/addons
#   * https://github.com/tensorflow/io (for I/O related ops)
# If you depend on functionality not listed there, please file an issue.
#
# Collecting ipython-autotime
#   Downloading https://files.pythonhosted.org/packages/e6/f9/0626bbdb322e3a078d968e87e3b01341e7890544de891d0cb613641220e6/ipython-autotime-0.1.tar.bz2
# Building wheels for collected packages: ipython-autotime
#   Building wheel for ipython-autotime (setup.py) ... done
#   Created wheel for ipython-autotime: filename=ipython_autotime-0.1-cp36-none-any.whl size=1832 sha256=3c079a0968698d9dc9dc36b25fa73418f768e4fba835f488e2e9dc13bf2746be
#   Stored in directory: /root/.cache/pip/wheels/d2/df/81/2db1e54bc91002cec40334629bc39cfa86dff540b304ebcd6e
# Successfully built ipython-autotime
# Installing collected packages: ipython-autotime
# Successfully installed ipython-autotime-0.1
#
# 7-Zip [64] 16.02 : Copyright (c) 1999-2016 Igor Pavlov : 2016-05-21
# p7zip Version 16.02 (locale=en_US.UTF-8,Utf16=on,HugeFiles=on,64 bits,2 CPUs Intel(R) Xeon(R) CPU @ 2.30GHz (306F0),ASM,AES-NI)
#
# Scanning the drive for archives:
# 1 file, 527055870 bytes (503 MiB)
#
# Extracting archive: NCA-Cropped.7z
# --
# Path = NCA-Cropped.7z
# Type = 7z
# Physical Size = 527055870
# Headers Size = 25800
# Method = LZMA2:24
# Solid = +
# Blocks = 1
#
# Everything is Ok
#
# Files: 3891
# Size:       1176779717
# Compressed: 527055870

# %%
os.mkdir('/content/RenamedImages/ClassN') 
# os.mkdir('/content/RenamedImages/ClassD')
os.mkdir('/content/RenamedImages/ClassC') 
os.mkdir('/content/RenamedImages/ClassA') 
# os.mkdir('/content/RenamedImages/ClassH') 
# os.mkdir('/content/RenamedImages/ClassM')
# os.mkdir('/content/RenamedImages/ClassO') 
# os.mkdir('/content/RenamedImages/ClassG')
for filename in os.listdir('/content/RenamedImages'): # files extracted from zip file
  directory = '/content/RenamedImages'
  directoryN = '/content/RenamedImages/ClassN'
  # directoryO = '/content/RenamedImages/ClassD'
  directoryC = '/content/RenamedImages/ClassC'
  directoryA = '/content/RenamedImages/ClassA'
  # directoryH = '/content/RenamedImages/ClassH'
  # directoryM = '/content/RenamedImages/ClassM'
  # directoryD = '/content/RenamedImages/ClassO'
  # directoryG = '/content/RenamedImages/ClassG'
  if filename.endswith('jpg'):
    if filename.startswith('N'):
      os.rename(os.path.join(directory,filename), os.path.join(directoryN,filename))
    # elif filename.startswith('D'):
    #   os.rename(os.path.join(directory,filename), os.path.join(directoryO,filename))
    elif filename.startswith('C'):
      os.rename(os.path.join(directory,filename), os.path.join(directoryC,filename))
    elif filename.startswith('A'):
      os.rename(os.path.join(directory,filename), os.path.join(directoryA,filename))
    # elif filename.startswith('H'):
    #   os.rename(os.path.join(directory,filename), os.path.join(directoryH,filename))
    # elif filename.startswith('M'):
    #   os.rename(os.path.join(directory,filename), os.path.join(directoryM,filename))
    # elif filename.startswith('O'):
    #   os.rename(os.path.join(directory,filename), os.path.join(directoryD,filename))
    # elif filename.startswith('G'):
    #   os.rename(os.path.join(directory,filename), os.path.join(directoryG,filename))

# !pip install split-folders tqdm
import split_folders
split_folders.ratio('/content/RenamedImages', output="output", seed=333, ratio=(.8, .1, .1))
# Out:
# Collecting split-folders
#   Downloading https://files.pythonhosted.org/packages/20/67/29dda743e6d23ac1ea3d16704d8bbb48d65faf3f1b1eaf53153b3da56c56/split_folders-0.3.1-py3-none-any.whl
# Requirement already satisfied: tqdm in /usr/local/lib/python3.6/dist-packages (4.28.1)
# Installing collected packages: split-folders
# Successfully installed split-folders-0.3.1
# Copying files: 3891 files [00:04, 848.75 files/s]
# time: 8.35 s

# %%
import torch
import torchvision
import torchvision.transforms as transforms

transform = transforms.Compose([ transforms.Resize((2000,2000)),
                                transforms.Grayscale(),
                                transforms.RandomHorizontalFlip(),
                                # torchvision.transforms.RandomRotation((0,180)),
                                transforms.ToTensor(), 
                                # transforms.Normalize((0.5,0.5,0.5),(0.5,0.5,0.5))
                                ])

trainset = torchvision.datasets.ImageFolder(root='/content/output/train', transform=transform)
trainloader = torch.utils.data.DataLoader(trainset, batch_size=1, shuffle=True, num_workers=0)#, collate_fn=my_collate,pin_memory=True))

testset = torchvision.datasets.ImageFolder(root='/content/output/test', transform=transform)
testloader = torch.utils.data.DataLoader(testset, batch_size=4, shuffle=False, num_workers=2)

valset = torchvision.datasets.ImageFolder(root='/content/output/val', target_transform=None)
valloader = torch.utils.data.DataLoader(valset, batch_size = 4,shuffle = True, num_workers = 2)
classes = ('Normal','Cataracts','AMD')#,'Hypertension','Myopia','Other')
# Out:
# time: 3.11 s

# %%
import torch.nn as nn
import torch.nn.functional as F

class Net(nn.Module):
    def __init__(self):
        super(Net, self).__init__()
        self.conv1 = nn.Conv2d(1, 6, 3) #in_channels, out_channels, kernel_size
        self.pool = nn.MaxPool2d(5, stride = 3)
        self.conv2 = nn.Conv2d(6, 16, 5)
        # self.conv3 = nn.Conv2d(16, 32, 7)
        self.fc1 = nn.Linear(16*219*219, 96)
        self.fc2 = nn.Linear(96, 8)
        self.fc3 = nn.Linear(8 , 3)
        self.dropout = nn.Dropout(0.5)
        # k= 
        # with torch.no_grad():
        # self.conv1.weight = torch.nn.Parameter(K)

    def forward(self, x):
        x = self.pool(F.relu(self.conv1(x)))
        # print('conv1', x.size())
        x = self.pool(F.relu(self.conv2(x)))
        # x = self.pool(F.relu(self.conv3(x)))
        # mask can be applied here
        print('conv2', x.size()) #16*219*219
        x = x.view(-1, 16*219*219) 
        # print(x.size())
        x = F.relu(self.fc1(x))
        # print(x.size())
        x = F.relu(self.fc2(x))
        x = self.fc3(x)
        return x

net = Net()
# Out:
# time: 614 ms

# %%
import torch.optim as optim

criterion = nn.CrossEntropyLoss()
optimizer = optim.Adam(net.parameters(), lr=0.001)#,momentum = 0.9)
# Out:
# time: 21.5 ms

# %%
# loading network
# net = TheModelClass(*args, **kwargs)
# optimizer = optim.Adam(net.parameters(), lr = 0.001)#, momentum = 0.9) 
# import torch

# checkpoint = torch.load('/content/NCA92%filt2000.tar')
# net.load_state_dict(checkpoint['net_state_dict'])
# optimizer.load_state_dict(checkpoint['optimizer_state_dict'])
# # epoch = 'epoch'
# loss = checkpoint['loss']

# net.eval()
# Out:
# time: 9.4 ms

# %%
from sklearn.metrics import f1_score
#normalize each image
def normalize(batch):
  # mean_red =0
  # mean_green = 0
  # mean_blue = 0
  # std_red = 0
  # std_green = 0
  # std_blue = 0
  mean_gray = 0
  std_gray = 0
  for i in range(batch.size(0)):
  #find rgb channel mean and std of image
    # mean_red += batch[i, 0, :, :].mean().item()
    # mean_green += batch[i, 1, :, :].mean().item()
    # mean_blue += batch[i,2, :, :].mean().item()
    # std_red += batch[i, 0, :, :].std()
    # std_green += batch[i,  1, :, :].std()
    # std_blue += batch[ i, 2, :, :].std()
  #find gray mean and std of image
    mean_gray = batch[i, 0, :, :].mean().item()
    std_gray = batch[i, 0, :, :].std()
  
  # mean_red = mean_red /batch.size(0)
  # mean_green = mean_green /batch.size(0)
  # mean_blue = mean_blue /batch.size(0)
  # std_red = std_red /batch.size(0)
  # std_green = std_green /batch.size(0)
  # std_blue = std_blue /batch.size(0)
  #for grayscale images
  # mean_gray = mean_gray /batch.size(0)
  # std_gray = std_gray /batch.size(0)
  for i in range(batch.size(0)):
    # #for rgb images
    # batch[i, 0, :, :] = (batch[i, 0, :, :] -mean_red)/std_red
    # batch[i, 1, :, :] = (batch[i, 1, :, :] -mean_green)/std_green
    # batch[i, 2, :, :] = (batch[i, 2, :, :] -mean_blue)/std_blue
    # for grayscale images
    batch[i, 0, :, :] = (batch[i, 0, :, :] -mean_gray)/std_gray
  return batch


epochacc = []
for epoch in range(1):  # loop over the dataset multiple times
    running_loss = 0.0
    correct = 0
    total = 0
    actuals = []
    pred = []
    for i, data in enumerate(trainloader, 0):
        # get the inputs; data is a list of [inputs, labels]
        # make mask here
        inputs, labels = data
        # mask = torch.empty(2000, 2000, dtype=torch.float)
        # print(inputs.size())
        # print('input[1]', (inputs[1]).size())
        # print('input[1]', inputs[1][1])
        # img1 = inputs[1]
        # mask = img1>30; #1; mask[img1<30] = 0 # tale first image of inputs 
        
        
        # inputs = normalize(inputs)
        print('labels:   ',labels)
        # zero the parameter gradients
        optimizer.zero_grad()

        # forward + backward + optimize
        outputs = net(inputs)
        # print(outputs)
        _, predicted = torch.max(outputs.data, 1)
        print('predicted:',predicted)
        loss = criterion(outputs, labels)
        loss.backward()
        optimizer.step()
        total += labels.size(0)
        correct += (predicted == labels).sum().item()
        # print statistics
        running_loss += loss.item()
        actuals.append(labels)
        pred.append(predicted)
        if i % 2000 == 1999:    # print every 2000 mini-batches
            print('[%d, %5d] loss: %.3f' %
                  (epoch + 1, i + 1, running_loss / 2000))
            running_loss = 0.0
    print('Accuracy of the network on the 100(0) training images: %d %%' % (
        100 * correct / total))
    epochacc.append(100 * correct / total)
    # f1_score(torch.cat(actuals,0), torch.cat(pred,0))

print('Finished Training', epochacc)
# Out:
# Streaming output truncated to the last 5000 lines.
# labels:    tensor([0])
# conv2 torch.Size([1, 16, 219, 219])
# predicted: tensor([0])
# labels:    tensor([2])
# conv2 torch.Size([1, 16, 219, 219])
# predicted: tensor([2])
# labels:    tensor([0])
# conv2 torch.Size([1, 16, 219, 219])
# predicted: tensor([0])
# labels:    tensor([1])
# conv2 torch.Size([1, 16, 219, 219])
# predicted: tensor([1])
# labels:    tensor([2])
# conv2 torch.Size([1, 16, 219, 219])
# predicted: tensor([0])
# labels:    tensor([1])
# conv2 torch.Size([1, 16, 219, 219])
# predicted: tensor([1])
# labels:    tensor([2])
# conv2 torch.Size([1, 16, 219, 219])
# predicted: tensor([2])
# labels:    tensor([1])
# conv2 torch.Size([1, 16, 219, 219])
# predicted: tensor([1])
# labels:    tensor([1])
# conv2 torch.Size([1, 16, 219, 219])
# predicted: tensor([1])
# labels:    tensor([1])
# conv2 torch.Size([1, 16, 219, 219])
# predicted: tensor([1])
# labels:    tensor([1])
# conv2 torch.Size([1, 16, 219, 219])
# predicted: tensor([1])
# labels:    tensor([2])
# conv2 torch.Size([1, 16, 219, 219])
# predicted: tensor([2])
# labels:    tensor([0])
# conv2 torch.Size([1, 16, 219, 219])
# predicted: tensor([0])
# labels:    tensor([1])
# conv2 torch.Size([1, 16, 219, 219])
# predicted: tensor([1])
# labels:    tensor([0])
# conv2 torch.Size([1, 16, 219, 219])
# predicted: tensor([2])
# labels:    tensor([1])
# conv2 torch.Size([1, 16, 219, 219])
# predicted: tensor([1])
# labels:    tensor([2])
# conv2 torch.Size([1, 16, 219, 219])
# predicted: tensor([2])
# labels:    tensor([1])
# conv2 torch.Size([1, 16, 219, 219])
# predicted: tensor([1])
# labels:    tensor([0])
# conv2 torch.Size([1, 16, 219, 219])
# predicted: tensor([0])
# labels:    tensor([2])
# conv2 torch.Size([1, 16, 219, 219])
# predicted: tensor([2])
# labels:    tensor([1])
# conv2 torch.Size([1, 16, 219, 219])
# predicted: tensor([1])
# labels:    tensor([0])
# conv2 torch.Size([1, 16, 219, 219])
# predicted: tensor([0])
# labels:    tensor([0])
# conv2 torch.Size([1, 16, 219, 219])
# predicted: tensor([0])
# labels:    tensor([2])
# conv2 torch.Size([1, 16, 219, 219])
# predicted: tensor([2])
# labels:    tensor([0])
# conv2 torch.Size([1, 16, 219, 219])
# predicted: tensor([0])
# labels:    tensor([1])
# conv2 torch.Size([1, 16, 219, 219])
# predicted: tensor([1])
# labels:    tensor([2])
# conv2 torch.Size([1, 16, 219, 219])
# predicted: tensor([2])
# labels:    tensor([0])
# conv2 torch.Size([1, 16, 219, 219])
# predicted: tensor([0])
# labels:    tensor([1])
# conv2 torch.Size([1, 16, 219, 219])
# predicted: tensor([1])
# labels:    tensor([0])
# conv2 torch.Size([1, 16, 219, 219])
# predicted: tensor([0])
# labels:    tensor([1])
# conv2 torch.Size([1, 16, 219, 219])
# predicted: tensor([1])
# labels:    tensor([0])
# conv2 torch.Size([1, 16, 219, 219])
# predicted: tensor([2])
# labels:    tensor([1])
# conv2 torch.Size([1, 16, 219, 219])
# predicted: tensor([1])
# labels:    tensor([2])
# conv2 torch.Size([1, 16, 219, 219])
# predicted: tensor([0])
# labels:    tensor([1])
# conv2 torch.Size([1, 16, 219, 219])
# predicted: tensor([1])
# labels:    tensor([1])
# conv2 torch.Size([1, 16, 219, 219])
# predicted: tensor([1])
# labels:    tensor([2])
# conv2 torch.Size([1, 16, 219, 219])
# predicted: tensor([0])
# labels:    tensor([0])
# conv2 torch.Size([1, 16, 219, 219])
# predicted: tensor([0])
# labels:    tensor([2])
# conv2 torch.Size([1, 16, 219, 219])
# predicted: tensor([2])
# labels:    tensor([1])
# conv2 torch.Size([1, 16, 219, 219])
# predicted: tensor([1])
# labels:    tensor([2])
# conv2 torch.Size([1, 16, 219, 219])
# predicted: tensor([2])
# labels:    tensor([0])
# conv2 torch.Size([1, 16, 219, 219])
# predicted: tensor([2])
# labels:    tensor([1])
# conv2 torch.Size([1, 16, 219, 219])
# predicted: tensor([1])
# labels:    tensor([1])
# conv2 torch.Size([1, 16, 219, 219])
# predicted: tensor([1])
# labels:    tensor([0])
# conv2 torch.Size([1, 16, 219, 219])
# predicted: tensor([0])
# labels:    tensor([1])
# conv2 torch.Size([1, 16, 219, 219])
# predicted: tensor([1])
# labels:    tensor([1])
# conv2 torch.Size([1, 16, 219, 219])
# predicted: tensor([1])
# labels:    tensor([0])
# conv2 torch.Size([1, 16, 219, 219])
# predicted: tensor([0])
# labels:    tensor([2])
# conv2 torch.Size([1, 16, 219, 219])
# predicted: tensor([2])
# labels:    tensor([2])
# conv2 torch.Size([1, 16, 219, 219])
# predicted: tensor([2])
# labels:    tensor([1])
# conv2 torch.Size([1, 16, 219, 219])
# predicted: tensor([1])
# labels:    tensor([1])
# conv2 torch.Size([1, 16, 219, 219])
# predicted: tensor([1])
# labels:    tensor([2])
# conv2 torch.Size([1, 16, 219, 219])
# predicted: tensor([2])
# labels:    tensor([1])
# conv2 torch.Size([1, 16, 219, 219])
# predicted: tensor([1])
# labels:    tensor([1])
# conv2 torch.Size([1, 16, 219, 219])
# predicted: tensor([1])
# labels:    tensor([2])
# conv2 torch.Size([1, 16, 219, 219])
# predicted: tensor([2])
# labels:    tensor([2])
# conv2 torch.Size([1, 16, 219, 219])
# predicted: tensor([0])
# labels:    tensor([2])
# conv2 torch.Size([1, 16, 219, 219])
# predicted: tensor([2])
# labels:    tensor([1])
# conv2 torch.Size([1, 16, 219, 219])
# predicted: tensor([1])
# labels:    tensor([0])
# conv2 torch.Size([1, 16, 219, 219])
# predicted: tensor([2])
# labels:    tensor([0])
# conv2 torch.Size([1, 16, 219, 219])
# predicted: tensor([2])
# labels:    tensor([0])
# conv2 torch.Size([1, 16, 219, 219])
# predicted: tensor([0])
# labels:    tensor([2])
# conv2 torch.Size([1, 16, 219, 219])
# predicted: tensor([2])
# labels:    tensor([0])
# conv2 torch.Size([1, 16, 219, 219])
# predicted: tensor([2])
# labels:    tensor([2])
# conv2 torch.Size([1, 16, 219, 219])
# predicted: tensor([2])
# labels:    tensor([0])
# conv2 torch.Size([1, 16, 219, 219])
# predicted: tensor([0])
# labels:    tensor([2])
# conv2 torch.Size([1, 16, 219, 219])
# predicted: tensor([2])
# labels:    tensor([2])
# conv2 torch.Size([1, 16, 219, 219])
# predicted: tensor([2])
# labels:    tensor([1])
# conv2 torch.Size([1, 16, 219, 219])
# predicted: tensor([1])
# labels:    tensor([1])
# conv2 torch.Size([1, 16, 219, 219])
# predicted: tensor([1])
# labels:    tensor([0])
# conv2 torch.Size([1, 16, 219, 219])
# predicted: tensor([0])
# labels:    tensor([2])
# conv2 torch.Size([1, 16, 219, 219])
# predicted: tensor([2])
# labels:    tensor([2])
# conv2 torch.Size([1, 16, 219, 219])
# predicted: tensor([2])
# labels:    tensor([0])
# conv2 torch.Size([1, 16, 219, 219])
# predicted: tensor([0])
# labels:    tensor([1])
# conv2 torch.Size([1, 16, 219, 219])
# predicted: tensor([1])
# labels:    tensor([0])
# conv2 torch.Size([1, 16, 219, 219])
# predicted: tensor([2])
# labels:    tensor([2])
# conv2 torch.Size([1, 16, 219, 219])
# predicted: tensor([2])
# labels:    tensor([0])
# conv2 torch.Size([1, 16, 219, 219])
# predicted: tensor([0])
# labels:    tensor([2])
# conv2 torch.Size([1, 16, 219, 219])
# predicted: tensor([2])
# labels:    tensor([0])
# conv2 torch.Size([1, 16, 219, 219])
# predicted: tensor([2])
# labels:    tensor([1])
# conv2 torch.Size([1, 16, 219, 219])
# predicted: tensor([1])
# labels:    tensor([2])
# conv2 torch.Size([1, 16, 219, 219])
# predicted: tensor([0])
# labels:    tensor([1])
# conv2 torch.Size([1, 16, 219, 219])
# predicted: tensor([1])
# labels:    tensor([2])
# conv2 torch.Size([1, 16, 219, 219])
# predicted: tensor([0])
# labels:    tensor([1])
# conv2 torch.Size([1, 16, 219, 219])
# predicted: tensor([1])
# labels:    tensor([2])
# conv2 torch.Size([1, 16, 219, 219])
# predicted: tensor([1])
# labels:    tensor([1])
# conv2 torch.Size([1, 16, 219, 219])
# predicted: tensor([1])
# labels:    tensor([1])
# conv2 torch.Size([1, 16, 219, 219])
# predicted: tensor([1])
# labels:    tensor([1])
# conv2 torch.Size([1, 16, 219, 219])
# predicted: tensor([1])
# labels:    tensor([2])
# conv2 torch.Size([1, 16, 219, 219])
# predicted: tensor([2])
# labels:    tensor([2])
# conv2 torch.Size([1, 16, 219, 219])
# predicted: tensor([0])
# labels:    tensor([0])
# conv2 torch.Size([1, 16, 219, 219])
# predicted: tensor([2])
# labels:    tensor([0])
# conv2 torch.Size([1, 16, 219, 219])
# predicted: tensor([0])
# labels:    tensor([1])
# conv2 torch.Size([1, 16, 219, 219])
# predicted: tensor([1])
# labels:    tensor([0])
# conv2 torch.Size([1, 16, 219, 219])
# predicted: tensor([0])
# labels:    tensor([2])
# conv2 torch.Size([1, 16, 219, 219])
# predicted: tensor([2])
# labels:    tensor([1])
# conv2 torch.Size([1, 16, 219, 219])
# predicted: tensor([1])
# labels:    tensor([2])
# conv2 torch.Size([1, 16, 219, 219])
# predicted: tensor([2])
# labels:    tensor([0])
# conv2 torch.Size([1, 16, 219, 219])
# predicted: tensor([0])
# labels:    tensor([0])
# conv2 torch.Size([1, 16, 219, 219])
# predicted: tensor([2])
# labels:    tensor([0])
# conv2 torch.Size([1, 16, 219, 219])
# predicted: tensor([0])
# labels:    tensor([0])
# conv2 torch.Size([1, 16, 219, 219])
# predicted: tensor([0])
# labels:    tensor([2])
# conv2 torch.Size([1, 16, 219, 219])
# predicted: tensor([0])
# labels:    tensor([1])
# conv2 torch.Size([1, 16, 219, 219])
# predicted: tensor([1])
# labels:    tensor([2])
# conv2 torch.Size([1, 16, 219, 219])
# predicted: tensor([0])
# labels:    tensor([0])
# conv2 torch.Size([1, 16, 219, 219])
# predicted: tensor([2])
# labels:    tensor([0])
# conv2 torch.Size([1, 16, 219, 219])
# predicted: tensor([0])
# labels:    tensor([2])
# conv2 torch.Size([1, 16, 219, 219])
# predicted: tensor([2])
# labels:    tensor([0])
# conv2 torch.Size([1, 16, 219, 219])
# predicted: tensor([0])
# labels:    tensor([0])
# conv2 torch.Size([1, 16, 219, 219])
# predicted: tensor([0])
# labels:    tensor([0])
# conv2 torch.Size([1, 16, 219, 219])
# predicted: tensor([0])
# labels:    tensor([1])
# conv2 torch.Size([1, 16, 219, 219])
# predicted: tensor([1])
# labels:    tensor([1])
# conv2 torch.Size([1, 16, 219, 219])
# predicted: tensor([1])
# labels:    tensor([1])
# conv2 torch.Size([1, 16, 219, 219])
# predicted: tensor([2])
# labels:    tensor([1])
# conv2 torch.Size([1, 16, 219, 219])
# predicted: tensor([1])
# labels:    tensor([0])
# conv2 torch.Size([1, 16, 219, 219])
# predicted: tensor([0])
# labels:    tensor([2])
# conv2 torch.Size([1, 16, 219, 219])
# predicted: tensor([0])
# labels:    tensor([1])
# conv2 torch.Size([1, 16, 219, 219])
# predicted: tensor([1])
# labels:    tensor([2])
# conv2 torch.Size([1, 16, 219, 219])
# predicted: tensor([2])
# labels:    tensor([2])
# conv2 torch.Size([1, 16, 219, 219])
# predicted: tensor([2])
# labels:    tensor([0])
# conv2 torch.Size([1, 16, 219, 219])
# predicted: tensor([0])
# labels:    tensor([2])
# conv2 torch.Size([1, 16, 219, 219])
# predicted: tensor([2])
# labels:    tensor([0])
# conv2 torch.Size([1, 16, 219, 219])
# predicted: tensor([2])
# labels:    tensor([1])
# conv2 torch.Size([1, 16, 219, 219])
# predicted: tensor([1])
# labels:    tensor([2])
# conv2 torch.Size([1, 16, 219, 219])
# predicted: tensor([2])
# labels:    tensor([0])
# conv2 torch.Size([1, 16, 219, 219])
# predicted: tensor([2])
# labels:    tensor([2])
# conv2 torch.Size([1, 16, 219, 219])
# predicted: tensor([2])
# labels:    tensor([0])
# conv2 torch.Size([1, 16, 219, 219])
# predicted: tensor([0])
# labels:    tensor([0])
# conv2 torch.Size([1, 16, 219, 219])
# predicted: tensor([2])
# labels:    tensor([2])
# conv2 torch.Size([1, 16, 219, 219])
# predicted: tensor([2])
# labels:    tensor([0])
# conv2 torch.Size([1, 16, 219, 219])
# predicted: tensor([2])
# labels:    tensor([1])
# conv2 torch.Size([1, 16, 219, 219])
# predicted: tensor([1])
# labels:    tensor([0])
# conv2 torch.Size([1, 16, 219, 219])
# predicted: tensor([0])
# labels:    tensor([0])
# conv2 torch.Size([1, 16, 219, 219])
# predicted: tensor([0])
# labels:    tensor([1])
# conv2 torch.Size([1, 16, 219, 219])
# predicted: tensor([1])
# labels:    tensor([1])
# conv2 torch.Size([1, 16, 219, 219])
# predicted: tensor([1])
# labels:    tensor([1])
# conv2 torch.Size([1, 16, 219, 219])
# predicted: tensor([1])
# labels:    tensor([2])
# conv2 torch.Size([1, 16, 219, 219])
# predicted: tensor([0])
# labels:    tensor([1])
# conv2 torch.Size([1, 16, 219, 219])
# predicted: tensor([1])
# labels:    tensor([2])
# conv2 torch.Size([1, 16, 219, 219])
# predicted: tensor([0])
# labels:    tensor([0])
# conv2 torch.Size([1, 16, 219, 219])
# predicted: tensor([0])
# labels:    tensor([2])
# conv2 torch.Size([1, 16, 219, 219])
# predicted: tensor([0])
# labels:    tensor([0])
# conv2 torch.Size([1, 16, 219, 219])
# predicted: tensor([0])
# labels:    tensor([0])
# conv2 torch.Size([1, 16, 219, 219])
# predicted: tensor([0])
# labels:    tensor([1])
# conv2 torch.Size([1, 16, 219, 219])
# predicted: tensor([1])
# labels:    tensor([0])
# conv2 torch.Size([1, 16, 219, 219])
# predicted: tensor([0])
# labels:    tensor([0])
# conv2 torch.Size([1, 16, 219, 219])
# predicted: tensor([2])
# labels:    tensor([0])
# conv2 torch.Size([1, 16, 219, 219])
# predicted: tensor([2])
# labels:    tensor([0])
# conv2 torch.Size([1, 16, 219, 219])
# predicted: tensor([0])
# labels:    tensor([0])
# conv2 torch.Size([1, 16, 219, 219])
# predicted: tensor([0])
# labels:    tensor([1])
# conv2 torch.Size([1, 16, 219, 219])
# predicted: tensor([1])
# labels:    tensor([2])
# conv2 torch.Size([1, 16, 219, 219])
# predicted: tensor([0])
# labels:    tensor([1])
# conv2 torch.Size([1, 16, 219, 219])
# predicted: tensor([1])
# labels:    tensor([1])
# conv2 torch.Size([1, 16, 219, 219])
# predicted: tensor([1])
# labels:    tensor([2])
# conv2 torch.Size([1, 16, 219, 219])
# predicted: tensor([0])
# labels:    tensor([1])
# conv2 torch.Size([1, 16, 219, 219])
# predicted: tensor([1])
# labels:    tensor([0])
# conv2 torch.Size([1, 16, 219, 219])
# predicted: tensor([0])
# labels:    tensor([2])
# conv2 torch.Size([1, 16, 219, 219])
# predicted: tensor([0])
# labels:    tensor([0])
# conv2 torch.Size([1, 16, 219, 219])
# predicted: tensor([0])
# labels:    tensor([1])
# conv2 torch.Size([1, 16, 219, 219])
# predicted: tensor([1])
# labels:    tensor([1])
# conv2 torch.Size([1, 16, 219, 219])
# predicted: tensor([1])
# labels:    tensor([0])
# conv2 torch.Size([1, 16, 219, 219])
# predicted: tensor([0])
# labels:    tensor([1])
# conv2 torch.Size([1, 16, 219, 219])
# predicted: tensor([1])
# labels:    tensor([0])
# conv2 torch.Size([1, 16, 219, 219])
# predicted: tensor([0])
# labels:    tensor([1])
# conv2 torch.Size([1, 16, 219, 219])
# predicted: tensor([1])
# labels:    tensor([1])
# conv2 torch.Size([1, 16, 219, 219])
# predicted: tensor([1])
# labels:    tensor([0])
# conv2 torch.Size([1, 16, 219, 219])
# predicted: tensor([0])
# labels:    tensor([1])
# conv2 torch.Size([1, 16, 219, 219])
# predicted: tensor([1])
# labels:    tensor([1])
# conv2 torch.Size([1, 16, 219, 219])
# predicted: tensor([1])
# labels:    tensor([0])
# conv2 torch.Size([1, 16, 219, 219])
# predicted: tensor([0])
# labels:    tensor([0])
# conv2 torch.Size([1, 16, 219, 219])
# predicted: tensor([0])
# labels:    tensor([2])
# conv2 torch.Size([1, 16, 219, 219])
# predicted: tensor([0])
# labels:    tensor([0])
# conv2 torch.Size([1, 16, 219, 219])
# predicted: tensor([0])
# labels:    tensor([2])
# conv2 torch.Size([1, 16, 219, 219])
# predicted: tensor([2])
# labels:    tensor([0])
# conv2 torch.Size([1, 16, 219, 219])
# predicted: tensor([0])
# labels:    tensor([0])
# conv2 torch.Size([1, 16, 219, 219])
# predicted: tensor([0])
# labels:    tensor([1])
# conv2 torch.Size([1, 16, 219, 219])
# predicted: tensor([1])
# labels:    tensor([1])
# conv2 torch.Size([1, 16, 219, 219])
# predicted: tensor([1])
# labels:    tensor([1])
# conv2 torch.Size([1, 16, 219, 219])
# predicted: tensor([1])
# labels:    tensor([0])
# conv2 torch.Size([1, 16, 219, 219])
# predicted: tensor([1])
# labels:    tensor([1])
# conv2 torch.Size([1, 16, 219, 219])
# predicted: tensor([1])
# labels:    tensor([1])
# conv2 torch.Size([1, 16, 219, 219])
# predicted: tensor([1])
# labels:    tensor([2])
# conv2 torch.Size([1, 16, 219, 219])
# predicted: tensor([0])
# labels:    tensor([0])
# conv2 torch.Size([1, 16, 219, 219])
# predicted: tensor([0])
# labels:    tensor([0])
# conv2 torch.Size([1, 16, 219, 219])
# predicted: tensor([0])
# labels:    tensor([0])
# conv2 torch.Size([1, 16, 219, 219])
# predicted: tensor([0])
# labels:    tensor([0])
# conv2 torch.Size([1, 16, 219, 219])
# predicted: tensor([0])
# labels:    tensor([2])
# conv2 torch.Size([1, 16, 219, 219])
# predicted: tensor([0])
# labels:    tensor([1])
# conv2 torch.Size([1, 16, 219, 219])
# predicted: tensor([1])
# labels:    tensor([2])
# conv2 torch.Size([1, 16, 219, 219])
# predicted: tensor([0])
# labels:    tensor([1])
# conv2 torch.Size([1, 16, 219, 219])
# predicted: tensor([1])
# labels:    tensor([2])
# conv2 torch.Size([1, 16, 219, 219])
# predicted: tensor([0])
# labels:    tensor([2])
# conv2 torch.Size([1, 16, 219, 219])
# predicted: tensor([0])
# labels:    tensor([1])
# conv2 torch.Size([1, 16, 219, 219])
# predicted: tensor([1])
# labels:    tensor([1])
# conv2 torch.Size([1, 16, 219, 219])
# predicted: tensor([1])
# labels:    tensor([0])
# conv2 torch.Size([1, 16, 219, 219])
# predicted: tensor([0])
# labels:    tensor([1])
# conv2 torch.Size([1, 16, 219, 219])
# predicted: tensor([1])
# labels:    tensor([1])
# conv2 torch.Size([1, 16, 219, 219])
# predicted: tensor([1])
# labels:    tensor([0])
# conv2 torch.Size([1, 16, 219, 219])
# predicted: tensor([0])
# labels:    tensor([2])
# conv2 torch.Size([1, 16, 219, 219])
# predicted: tensor([0])
# labels:    tensor([0])
# conv2 torch.Size([1, 16, 219, 219])
# predicted: tensor([0])
# labels:    tensor([2])
# conv2 torch.Size([1, 16, 219, 219])
# predicted: tensor([2])
# labels:    tensor([2])
# conv2 torch.Size([1, 16, 219, 219])
# predicted: tensor([0])
# labels:    tensor([0])
# conv2 torch.Size([1, 16, 219, 219])
# predicted: tensor([2])
# labels:    tensor([1])
# conv2 torch.Size([1, 16, 219, 219])
# predicted: tensor([1])
# labels:    tensor([1])
# conv2 torch.Size([1, 16, 219, 219])
# predicted: tensor([1])
# labels:    tensor([0])
# conv2 torch.Size([1, 16, 219, 219])
# predicted: tensor([0])
# labels:    tensor([0])
# conv2 torch.Size([1, 16, 219, 219])
# predicted: tensor([0])
# labels:    tensor([1])
# conv2 torch.Size([1, 16, 219, 219])
# predicted: tensor([1])
# labels:    tensor([0])
# conv2 torch.Size([1, 16, 219, 219])
# predicted: tensor([0])
# labels:    tensor([0])
# conv2 torch.Size([1, 16, 219, 219])
# predicted: tensor([0])
# labels:    tensor([1])
# conv2 torch.Size([1, 16, 219, 219])
# predicted: tensor([2])
# labels:    tensor([1])
# conv2 torch.Size([1, 16, 219, 219])
# predicted: tensor([1])
# labels:    tensor([1])
# conv2 torch.Size([1, 16, 219, 219])
# predicted: tensor([1])
# labels:    tensor([0])
# conv2 torch.Size([1, 16, 219, 219])
# predicted: tensor([0])
# labels:    tensor([1])
# conv2 torch.Size([1, 16, 219, 219])
# predicted: tensor([1])
# labels:    tensor([2])
# conv2 torch.Size([1, 16, 219, 219])
# predicted: tensor([2])
# labels:    tensor([0])
# conv2 torch.Size([1, 16, 219, 219])
# predicted: tensor([2])
# labels:    tensor([2])
# conv2 torch.Size([1, 16, 219, 219])
# predicted: tensor([2])
# labels:    tensor([0])
# conv2 torch.Size([1, 16, 219, 219])
# predicted: tensor([0])
# labels:    tensor([0])
# conv2 torch.Size([1, 16, 219, 219])
# predicted: tensor([2])
# labels:    tensor([0])
# conv2 torch.Size([1, 16, 219, 219])
# predicted: tensor([2])
# labels:    tensor([2])
# conv2 torch.Size([1, 16, 219, 219])
# predicted: tensor([2])
# labels:    tensor([1])
# conv2 torch.Size([1, 16, 219, 219])
# predicted: tensor([1])
# labels:    tensor([2])
# conv2 torch.Size([1, 16, 219, 219])
# predicted: tensor([2])
# labels:    tensor([1])
# conv2 torch.Size([1, 16, 219, 219])
# predicted: tensor([1])
# labels:    tensor([0])
# conv2 torch.Size([1, 16, 219, 219])
# predicted: tensor([0])
# labels:    tensor([1])
# conv2 torch.Size([1, 16, 219, 219])
# predicted: tensor([1])
# labels:    tensor([0])
# conv2 torch.Size([1, 16, 219, 219])
# predicted: tensor([0])
# labels:    tensor([2])
# conv2 torch.Size([1, 16, 219, 219])
# predicted: tensor([2])
# labels:    tensor([1])
# conv2 torch.Size([1, 16, 219, 219])
# predicted: tensor([1])
# labels:    tensor([0])
# conv2 torch.Size([1, 16, 219, 219])
# predicted: tensor([0])
# labels:    tensor([1])
# conv2 torch.Size([1, 16, 219, 219])
# predicted: tensor([1])
# labels:    tensor([1])
# conv2 torch.Size([1, 16, 219, 219])
# predicted: tensor([1])
# labels:    tensor([1])
# conv2 torch.Size([1, 16, 219, 219])
# predicted: tensor([1])
# labels:    tensor([2])
# conv2 torch.Size([1, 16, 219, 219])
# predicted: tensor([0])
# labels:    tensor([0])
# conv2 torch.Size([1, 16, 219, 219])
# predicted: tensor([0])
# labels:    tensor([0])
# conv2 torch.Size([1, 16, 219, 219])
# predicted: tensor([0])
# labels:    tensor([2])
# conv2 torch.Size([1, 16, 219, 219])
# predicted: tensor([2])
# labels:    tensor([1])
# conv2 torch.Size([1, 16, 219, 219])
# predicted: tensor([1])
# labels:    tensor([1])
# conv2 torch.Size([1, 16, 219, 219])
# predicted: tensor([1])
# labels:    tensor([0])
# conv2 torch.Size([1, 16, 219, 219])
# predicted: tensor([2])
# labels:    tensor([0])
# conv2 torch.Size([1, 16, 219, 219])
# predicted: tensor([0])
# labels:    tensor([2])
# conv2 torch.Size([1, 16, 219, 219])
# predicted: tensor([2])
# labels:    tensor([2])
# conv2 torch.Size([1, 16, 219, 219])
# predicted: tensor([2])
# labels:    tensor([2])
# conv2 torch.Size([1, 16, 219, 219])
# predicted: tensor([0])
# labels:    tensor([1])
# conv2 torch.Size([1, 16, 219, 219])
# predicted: tensor([1])
# labels:    tensor([0])
# conv2 torch.Size([1, 16, 219, 219])
# predicted: tensor([2])
# labels:    tensor([0])
# conv2 torch.Size([1, 16, 219, 219])
# predicted: tensor([0])
# labels:    tensor([1])
# conv2 torch.Size([1, 16, 219, 219])
# predicted: tensor([1])
# labels:    tensor([1])
# conv2 torch.Size([1, 16, 219, 219])
# predicted: tensor([1])
# labels:    tensor([2])
# conv2 torch.Size([1, 16, 219, 219])
# predicted: tensor([0])
# labels:    tensor([0])
# conv2 torch.Size([1, 16, 219, 219])
# predicted: tensor([0])
# labels:    tensor([0])
# conv2 torch.Size([1, 16, 219, 219])
# predicted: tensor([0])
# labels:    tensor([0])
# conv2 torch.Size([1, 16, 219, 219])
# predicted: tensor([0])
# labels:    tensor([0])
# conv2 torch.Size([1, 16, 219, 219])
# predicted: tensor([0])
# labels:    tensor([0])
# conv2 torch.Size([1, 16, 219, 219])
# predicted: tensor([2])
# labels:    tensor([2])
# conv2 torch.Size([1, 16, 219, 219])
# predicted: tensor([2])
# labels:    tensor([2])
# conv2 torch.Size([1, 16, 219, 219])
# predicted: tensor([2])
# labels:    tensor([0])
# conv2 torch.Size([1, 16, 219, 219])
# predicted: tensor([0])
# labels:    tensor([0])
# conv2 torch.Size([1, 16, 219, 219])
# predicted: tensor([0])
# labels:    tensor([2])
# conv2 torch.Size([1, 16, 219, 219])
# predicted: tensor([1])
# labels:    tensor([2])
# conv2 torch.Size([1, 16, 219, 219])
# predicted: tensor([2])
# labels:    tensor([1])
# conv2 torch.Size([1, 16, 219, 219])
# predicted: tensor([1])
# labels:    tensor([0])
# conv2 torch.Size([1, 16, 219, 219])
# predicted: tensor([0])
# labels:    tensor([1])
# conv2 torch.Size([1, 16, 219, 219])
# predicted: tensor([1])
# labels:    tensor([2])
# conv2 torch.Size([1, 16, 219, 219])
# predicted: tensor([0])
# labels:    tensor([1])
# conv2 torch.Size([1, 16, 219, 219])
# predicted: tensor([1])
# labels:    tensor([0])
# conv2 torch.Size([1, 16, 219, 219])
# predicted: tensor([0])
# labels:    tensor([0])
# conv2 torch.Size([1, 16, 219, 219])
# predicted: tensor([0])
# labels:    tensor([1])
# conv2 torch.Size([1, 16, 219, 219])
# predicted: tensor([1])
# labels:    tensor([2])
# conv2 torch.Size([1, 16, 219, 219])
# predicted: tensor([2])
# labels:    tensor([0])
# conv2 torch.Size([1, 16, 219, 219])
# predicted: tensor([0])
# labels:    tensor([2])
# conv2 torch.Size([1, 16, 219, 219])
# predicted: tensor([2])
# labels:    tensor([0])
# conv2 torch.Size([1, 16, 219, 219])
# predicted: tensor([0])
# labels:    tensor([2])
# conv2 torch.Size([1, 16, 219, 219])
# predicted: tensor([2])
# labels:    tensor([0])
# conv2 torch.Size([1, 16, 219, 219])
# predicted: tensor([0])
# labels:    tensor([1])
# conv2 torch.Size([1, 16, 219, 219])
# predicted: tensor([1])
# labels:    tensor([0])
# conv2 torch.Size([1, 16, 219, 219])
# predicted: tensor([0])
# labels:    tensor([0])
# conv2 torch.Size([1, 16, 219, 219])
# predicted: tensor([0])
# labels:    tensor([2])
# conv2 torch.Size([1, 16, 219, 219])
# predicted: tensor([0])
# labels:    tensor([1])
# conv2 torch.Size([1, 16, 219, 219])
# predicted: tensor([1])
# labels:    tensor([1])
# conv2 torch.Size([1, 16, 219, 219])
# predicted: tensor([1])
# labels:    tensor([2])
# conv2 torch.Size([1, 16, 219, 219])
# predicted: tensor([2])
# labels:    tensor([1])
# conv2 torch.Size([1, 16, 219, 219])
# predicted: tensor([1])
# labels:    tensor([2])
# conv2 torch.Size([1, 16, 219, 219])
# predicted: tensor([2])
# labels:    tensor([2])
# conv2 torch.Size([1, 16, 219, 219])
# predicted: tensor([2])
# labels:    tensor([1])
# conv2 torch.Size([1, 16, 219, 219])
# predicted: tensor([1])
# labels:    tensor([0])
# conv2 torch.Size([1, 16, 219, 219])
# predicted: tensor([0])
# labels:    tensor([0])
# conv2 torch.Size([1, 16, 219, 219])
# predicted: tensor([0])
# labels:    tensor([2])
# conv2 torch.Size([1, 16, 219, 219])
# predicted: tensor([2])
# labels:    tensor([0])
# conv2 torch.Size([1, 16, 219, 219])
# predicted: tensor([0])
# labels:    tensor([1])
# conv2 torch.Size([1, 16, 219, 219])
# predicted: tensor([1])
# labels:    tensor([0])
# conv2 torch.Size([1, 16, 219, 219])
# predicted: tensor([2])
# labels:    tensor([2])
# conv2 torch.Size([1, 16, 219, 219])
# predicted: tensor([2])
# labels:    tensor([1])
# conv2 torch.Size([1, 16, 219, 219])
# predicted: tensor([1])
# labels:    tensor([1])
# conv2 torch.Size([1, 16, 219, 219])
# predicted: tensor([1])
# labels:    tensor([2])
# conv2 torch.Size([1, 16, 219, 219])
# predicted: tensor([2])
# labels:    tensor([0])
# conv2 torch.Size([1, 16, 219, 219])
# predicted: tensor([2])
# labels:    tensor([1])
# conv2 torch.Size([1, 16, 219, 219])
# predicted: tensor([1])
# labels:    tensor([2])
# conv2 torch.Size([1, 16, 219, 219])
# predicted: tensor([0])
# labels:    tensor([1])
# conv2 torch.Size([1, 16, 219, 219])
# predicted: tensor([2])
# labels:    tensor([2])
# conv2 torch.Size([1, 16, 219, 219])
# predicted: tensor([2])
# labels:    tensor([1])
# conv2 torch.Size([1, 16, 219, 219])
# predicted: tensor([1])
# labels:    tensor([0])
# conv2 torch.Size([1, 16, 219, 219])
# predicted: tensor([0])
# labels:    tensor([0])
# conv2 torch.Size([1, 16, 219, 219])
# predicted: tensor([2])
# labels:    tensor([2])
# conv2 torch.Size([1, 16, 219, 219])
# predicted: tensor([2])
# labels:    tensor([0])
# conv2 torch.Size([1, 16, 219, 219])
# predicted: tensor([2])
# labels:    tensor([2])
# conv2 torch.Size([1, 16, 219, 219])
# predicted: tensor([2])
# labels:    tensor([0])
# conv2 torch.Size([1, 16, 219, 219])
# predicted: tensor([0])
# labels:    tensor([2])
# conv2 torch.Size([1, 16, 219, 219])
# predicted: tensor([2])
# labels:    tensor([1])
# conv2 torch.Size([1, 16, 219, 219])
# predicted: tensor([1])
# labels:    tensor([2])
# conv2 torch.Size([1, 16, 219, 219])
# predicted: tensor([2])
# labels:    tensor([2])
# conv2 torch.Size([1, 16, 219, 219])
# predicted: tensor([2])
# labels:    tensor([1])
# conv2 torch.Size([1, 16, 219, 219])
# predicted: tensor([1])
# labels:    tensor([1])
# conv2 torch.Size([1, 16, 219, 219])
# predicted: tensor([1])
# labels:    tensor([1])
# conv2 torch.Size([1, 16, 219, 219])
# predicted: tensor([1])
# labels:    tensor([0])
# conv2 torch.Size([1, 16, 219, 219])
# predicted: tensor([0])
# labels:    tensor([1])
# conv2 torch.Size([1, 16, 219, 219])
# predicted: tensor([1])
# labels:    tensor([2])
# conv2 torch.Size([1, 16, 219, 219])
# predicted: tensor([2])
# labels:    tensor([1])
# conv2 torch.Size([1, 16, 219, 219])
# predicted: tensor([1])
# labels:    tensor([2])
# conv2 torch.Size([1, 16, 219, 219])
# predicted: tensor([0])
# labels:    tensor([0])
# conv2 torch.Size([1, 16, 219, 219])
# predicted: tensor([2])
# labels:    tensor([2])
# conv2 torch.Size([1, 16, 219, 219])
# predicted: tensor([2])
# labels:    tensor([0])
# conv2 torch.Size([1, 16, 219, 219])
# predicted: tensor([0])
# labels:    tensor([2])
# conv2 torch.Size([1, 16, 219, 219])
# predicted: tensor([2])
# labels:    tensor([1])
# conv2 torch.Size([1, 16, 219, 219])
# predicted: tensor([1])
# labels:    tensor([1])
# conv2 torch.Size([1, 16, 219, 219])
# predicted: tensor([1])
# labels:    tensor([2])
# conv2 torch.Size([1, 16, 219, 219])
# predicted: tensor([1])
# labels:    tensor([1])
# conv2 torch.Size([1, 16, 219, 219])
# predicted: tensor([1])
# labels:    tensor([1])
# conv2 torch.Size([1, 16, 219, 219])
# predicted: tensor([1])
# labels:    tensor([1])
# conv2 torch.Size([1, 16, 219, 219])
# predicted: tensor([2])
# labels:    tensor([2])
# conv2 torch.Size([1, 16, 219, 219])
# predicted: tensor([2])
# labels:    tensor([0])
# conv2 torch.Size([1, 16, 219, 219])
# predicted: tensor([0])
# labels:    tensor([1])
# conv2 torch.Size([1, 16, 219, 219])
# predicted: tensor([1])
# labels:    tensor([2])
# conv2 torch.Size([1, 16, 219, 219])
# predicted: tensor([2])
# labels:    tensor([1])
# conv2 torch.Size([1, 16, 219, 219])
# predicted: tensor([2])
# labels:    tensor([2])
# conv2 torch.Size([1, 16, 219, 219])
# predicted: tensor([2])
# labels:    tensor([0])
# conv2 torch.Size([1, 16, 219, 219])
# predicted: tensor([2])
# labels:    tensor([2])
# conv2 torch.Size([1, 16, 219, 219])
# predicted: tensor([2])
# labels:    tensor([0])
# conv2 torch.Size([1, 16, 219, 219])
# predicted: tensor([1])
# labels:    tensor([0])
# conv2 torch.Size([1, 16, 219, 219])
# predicted: tensor([2])
# labels:    tensor([2])
# conv2 torch.Size([1, 16, 219, 219])
# predicted: tensor([2])
# labels:    tensor([0])
# conv2 torch.Size([1, 16, 219, 219])
# predicted: tensor([0])
# labels:    tensor([0])
# conv2 torch.Size([1, 16, 219, 219])
# predicted: tensor([0])
# labels:    tensor([0])
# conv2 torch.Size([1, 16, 219, 219])
# predicted: tensor([2])
# labels:    tensor([0])
# conv2 torch.Size([1, 16, 219, 219])
# predicted: tensor([0])
# labels:    tensor([1])
# conv2 torch.Size([1, 16, 219, 219])
# predicted: tensor([1])
# labels:    tensor([0])
# conv2 torch.Size([1, 16, 219, 219])
# predicted: tensor([0])
# labels:    tensor([1])
# conv2 torch.Size([1, 16, 219, 219])
# predicted: tensor([1])
# labels:    tensor([1])
# conv2 torch.Size([1, 16, 219, 219])
# predicted: tensor([1])
# labels:    tensor([2])
# conv2 torch.Size([1, 16, 219, 219])
# predicted: tensor([0])
# labels:    tensor([2])
# conv2 torch.Size([1, 16, 219, 219])
# predicted: tensor([0])
# labels:    tensor([0])
# conv2 torch.Size([1, 16, 219, 219])
# predicted: tensor([0])
# labels:    tensor([1])
# conv2 torch.Size([1, 16, 219, 219])
# predicted: tensor([1])
# labels:    tensor([0])
# conv2 torch.Size([1, 16, 219, 219])
# predicted: tensor([0])
# labels:    tensor([2])
# conv2 torch.Size([1, 16, 219, 219])
# predicted: tensor([1])
# labels:    tensor([0])
# conv2 torch.Size([1, 16, 219, 219])
# predicted: tensor([0])
# labels:    tensor([2])
# conv2 torch.Size([1, 16, 219, 219])
# predicted: tensor([0])
# labels:    tensor([2])
# conv2 torch.Size([1, 16, 219, 219])
# predicted: tensor([2])
# labels:    tensor([2])
# conv2 torch.Size([1, 16, 219, 219])
# predicted: tensor([0])
# labels:    tensor([2])
# conv2 torch.Size([1, 16, 219, 219])
# predicted: tensor([0])
# labels:    tensor([0])
# conv2 torch.Size([1, 16, 219, 219])
# predicted: tensor([0])
# labels:    tensor([2])
# conv2 torch.Size([1, 16, 219, 219])
# predicted: tensor([1])
# labels:    tensor([0])
# conv2 torch.Size([1, 16, 219, 219])
# predicted: tensor([0])
# labels:    tensor([1])
# conv2 torch.Size([1, 16, 219, 219])
# predicted: tensor([1])
# labels:    tensor([0])
# conv2 torch.Size([1, 16, 219, 219])
# predicted: tensor([0])
# labels:    tensor([0])
# conv2 torch.Size([1, 16, 219, 219])
# predicted: tensor([0])
# labels:    tensor([0])
# conv2 torch.Size([1, 16, 219, 219])
# predicted: tensor([0])
# labels:    tensor([0])
# conv2 torch.Size([1, 16, 219, 219])
# predicted: tensor([2])
# labels:    tensor([2])
# conv2 torch.Size([1, 16, 219, 219])
# predicted: tensor([0])
# labels:    tensor([1])
# conv2 torch.Size([1, 16, 219, 219])
# predicted: tensor([1])
# labels:    tensor([2])
# conv2 torch.Size([1, 16, 219, 219])
# predicted: tensor([2])
# labels:    tensor([0])
# conv2 torch.Size([1, 16, 219, 219])
# predicted: tensor([0])
# labels:    tensor([0])
# conv2 torch.Size([1, 16, 219, 219])
# predicted: tensor([0])
# labels:    tensor([1])
# conv2 torch.Size([1, 16, 219, 219])
# predicted: tensor([1])
# labels:    tensor([2])
# conv2 torch.Size([1, 16, 219, 219])
# predicted: tensor([2])
# labels:    tensor([0])
# conv2 torch.Size([1, 16, 219, 219])
# predicted: tensor([0])
# labels:    tensor([0])
# conv2 torch.Size([1, 16, 219, 219])
# predicted: tensor([0])
# labels:    tensor([1])
# conv2 torch.Size([1, 16, 219, 219])
# predicted: tensor([1])
# labels:    tensor([1])
# conv2 torch.Size([1, 16, 219, 219])
# predicted: tensor([1])
# labels:    tensor([1])
# conv2 torch.Size([1, 16, 219, 219])
# predicted: tensor([1])
# labels:    tensor([2])
# conv2 torch.Size([1, 16, 219, 219])
# predicted: tensor([0])
# labels:    tensor([0])
# conv2 torch.Size([1, 16, 219, 219])
# predicted: tensor([0])
# labels:    tensor([0])
# conv2 torch.Size([1, 16, 219, 219])
# predicted: tensor([0])
# labels:    tensor([2])
# conv2 torch.Size([1, 16, 219, 219])
# predicted: tensor([2])
# labels:    tensor([0])
# conv2 torch.Size([1, 16, 219, 219])
# predicted: tensor([0])
# labels:    tensor([2])
# conv2 torch.Size([1, 16, 219, 219])
# predicted: tensor([0])
# labels:    tensor([2])
# conv2 torch.Size([1, 16, 219, 219])
# predicted: tensor([2])
# labels:    tensor([2])
# conv2 torch.Size([1, 16, 219, 219])
# predicted: tensor([2])
# labels:    tensor([0])
# conv2 torch.Size([1, 16, 219, 219])
# predicted: tensor([0])
# labels:    tensor([0])
# conv2 torch.Size([1, 16, 219, 219])
# predicted: tensor([0])
# labels:    tensor([1])
# conv2 torch.Size([1, 16, 219, 219])
# predicted: tensor([1])
# labels:    tensor([2])
# conv2 torch.Size([1, 16, 219, 219])
# predicted: tensor([0])
# labels:    tensor([2])
# conv2 torch.Size([1, 16, 219, 219])
# predicted: tensor([2])
# labels:    tensor([2])
# conv2 torch.Size([1, 16, 219, 219])
# predicted: tensor([2])
# labels:    tensor([2])
# conv2 torch.Size([1, 16, 219, 219])
# predicted: tensor([2])
# labels:    tensor([2])
# conv2 torch.Size([1, 16, 219, 219])
# predicted: tensor([2])
# labels:    tensor([0])
# conv2 torch.Size([1, 16, 219, 219])
# predicted: tensor([0])
# labels:    tensor([0])
# conv2 torch.Size([1, 16, 219, 219])
# predicted: tensor([0])
# labels:    tensor([0])
# conv2 torch.Size([1, 16, 219, 219])
# predicted: tensor([0])
# labels:    tensor([2])
# conv2 torch.Size([1, 16, 219, 219])
# predicted: tensor([2])
# labels:    tensor([2])
# conv2 torch.Size([1, 16, 219, 219])
# predicted: tensor([2])
# labels:    tensor([2])
# conv2 torch.Size([1, 16, 219, 219])
# predicted: tensor([2])
# labels:    tensor([2])
# conv2 torch.Size([1, 16, 219, 219])
# predicted: tensor([2])
# labels:    tensor([1])
# conv2 torch.Size([1, 16, 219, 219])
# predicted: tensor([1])
# labels:    tensor([2])
# conv2 torch.Size([1, 16, 219, 219])
# predicted: tensor([2])
# labels:    tensor([1])
# conv2 torch.Size([1, 16, 219, 219])
# predicted: tensor([1])
# labels:    tensor([1])
# conv2 torch.Size([1, 16, 219, 219])
# predicted: tensor([1])
# labels:    tensor([0])
# conv2 torch.Size([1, 16, 219, 219])
# predicted: tensor([2])
# labels:    tensor([2])
# conv2 torch.Size([1, 16, 219, 219])
# predicted: tensor([2])
# labels:    tensor([0])
# conv2 torch.Size([1, 16, 219, 219])
# predicted: tensor([2])
# labels:    tensor([2])
# conv2 torch.Size([1, 16, 219, 219])
# predicted: tensor([2])
# labels:    tensor([2])
# conv2 torch.Size([1, 16, 219, 219])
# predicted: tensor([2])
# labels:    tensor([0])
# conv2 torch.Size([1, 16, 219, 219])
# predicted: tensor([0])
# labels:    tensor([1])
# conv2 torch.Size([1, 16, 219, 219])
# predicted: tensor([2])
# labels:    tensor([0])
# conv2 torch.Size([1, 16, 219, 219])
# predicted: tensor([2])
# labels:    tensor([0])
# conv2 torch.Size([1, 16, 219, 219])
# predicted: tensor([0])
# labels:    tensor([2])
# conv2 torch.Size([1, 16, 219, 219])
# predicted: tensor([2])
# labels:    tensor([1])
# conv2 torch.Size([1, 16, 219, 219])
# predicted: tensor([1])
# labels:    tensor([1])
# conv2 torch.Size([1, 16, 219, 219])
# predicted: tensor([1])
# labels:    tensor([0])
# conv2 torch.Size([1, 16, 219, 219])
# predicted: tensor([0])
# labels:    tensor([2])
# conv2 torch.Size([1, 16, 219, 219])
# predicted: tensor([2])
# labels:    tensor([1])
# conv2 torch.Size([1, 16, 219, 219])
# predicted: tensor([1])
# labels:    tensor([1])
# conv2 torch.Size([1, 16, 219, 219])
# predicted: tensor([1])
# labels:    tensor([2])
# conv2 torch.Size([1, 16, 219, 219])
# predicted: tensor([0])
# labels:    tensor([1])
# conv2 torch.Size([1, 16, 219, 219])
# predicted: tensor([1])
# labels:    tensor([0])
# conv2 torch.Size([1, 16, 219, 219])
# predicted: tensor([0])
# labels:    tensor([1])
# conv2 torch.Size([1, 16, 219, 219])
# predicted: tensor([2])
# labels:    tensor([2])
# conv2 torch.Size([1, 16, 219, 219])
# predicted: tensor([2])
# labels:    tensor([2])
# conv2 torch.Size([1, 16, 219, 219])
# predicted: tensor([2])
# labels:    tensor([1])
# conv2 torch.Size([1, 16, 219, 219])
# predicted: tensor([1])
# labels:    tensor([1])
# conv2 torch.Size([1, 16, 219, 219])
# predicted: tensor([1])
# labels:    tensor([1])
# conv2 torch.Size([1, 16, 219, 219])
# predicted: tensor([1])
# labels:    tensor([2])
# conv2 torch.Size([1, 16, 219, 219])
# predicted: tensor([0])
# labels:    tensor([2])
# conv2 torch.Size([1, 16, 219, 219])
# predicted: tensor([2])
# labels:    tensor([1])
# conv2 torch.Size([1, 16, 219, 219])
# predicted: tensor([1])
# labels:    tensor([2])
# conv2 torch.Size([1, 16, 219, 219])
# predicted: tensor([0])
# labels:    tensor([0])
# conv2 torch.Size([1, 16, 219, 219])
# predicted: tensor([0])
# labels:    tensor([1])
# conv2 torch.Size([1, 16, 219, 219])
# predicted: tensor([1])
# labels:    tensor([0])
# conv2 torch.Size([1, 16, 219, 219])
# predicted: tensor([0])
# labels:    tensor([1])
# conv2 torch.Size([1, 16, 219, 219])
# predicted: tensor([1])
# labels:    tensor([0])
# conv2 torch.Size([1, 16, 219, 219])
# predicted: tensor([0])
# labels:    tensor([0])
# conv2 torch.Size([1, 16, 219, 219])
# predicted: tensor([0])
# labels:    tensor([1])
# conv2 torch.Size([1, 16, 219, 219])
# predicted: tensor([1])
# labels:    tensor([0])
# conv2 torch.Size([1, 16, 219, 219])
# predicted: tensor([0])
# labels:    tensor([1])
# conv2 torch.Size([1, 16, 219, 219])
# predicted: tensor([1])
# labels:    tensor([0])
# conv2 torch.Size([1, 16, 219, 219])
# predicted: tensor([0])
# labels:    tensor([1])
# conv2 torch.Size([1, 16, 219, 219])
# predicted: tensor([1])
# labels:    tensor([1])
# conv2 torch.Size([1, 16, 219, 219])
# predicted: tensor([1])
# labels:    tensor([1])
# conv2 torch.Size([1, 16, 219, 219])
# predicted: tensor([1])
# labels:    tensor([0])
# conv2 torch.Size([1, 16, 219, 219])
# predicted: tensor([0])
# labels:    tensor([1])
# conv2 torch.Size([1, 16, 219, 219])
# predicted: tensor([1])
# labels:    tensor([0])
# conv2 torch.Size([1, 16, 219, 219])
# predicted: tensor([0])
# labels:    tensor([0])
# conv2 torch.Size([1, 16, 219, 219])
# predicted: tensor([0])
# labels:    tensor([1])
# conv2 torch.Size([1, 16, 219, 219])
# predicted: tensor([1])
# labels:    tensor([0])
# conv2 torch.Size([1, 16, 219, 219])
# predicted: tensor([0])
# labels:    tensor([2])
# conv2 torch.Size([1, 16, 219, 219])
# predicted: tensor([2])
# labels:    tensor([0])
# conv2 torch.Size([1, 16, 219, 219])
# predicted: tensor([0])
# labels:    tensor([2])
# conv2 torch.Size([1, 16, 219, 219])
# predicted: tensor([0])
# labels:    tensor([0])
# conv2 torch.Size([1, 16, 219, 219])
# predicted: tensor([0])
# labels:    tensor([0])
# conv2 torch.Size([1, 16, 219, 219])
# predicted: tensor([0])
# labels:    tensor([1])
# conv2 torch.Size([1, 16, 219, 219])
# predicted: tensor([1])
# labels:    tensor([0])
# conv2 torch.Size([1, 16, 219, 219])
# predicted: tensor([0])
# labels:    tensor([1])
# conv2 torch.Size([1, 16, 219, 219])
# predicted: tensor([1])
# labels:    tensor([1])
# conv2 torch.Size([1, 16, 219, 219])
# predicted: tensor([1])
# labels:    tensor([2])
# conv2 torch.Size([1, 16, 219, 219])
# predicted: tensor([0])
# labels:    tensor([2])
# conv2 torch.Size([1, 16, 219, 219])
# predicted: tensor([0])
# labels:    tensor([1])
# conv2 torch.Size([1, 16, 219, 219])
# predicted: tensor([1])
# labels:    tensor([2])
# conv2 torch.Size([1, 16, 219, 219])
# predicted: tensor([2])
# labels:    tensor([1])
# conv2 torch.Size([1, 16, 219, 219])
# predicted: tensor([1])
# labels:    tensor([0])
# conv2 torch.Size([1, 16, 219, 219])
# predicted: tensor([0])
# labels:    tensor([1])
# conv2 torch.Size([1, 16, 219, 219])
# predicted: tensor([1])
# labels:    tensor([1])
# conv2 torch.Size([1, 16, 219, 219])
# predicted: tensor([1])
# labels:    tensor([1])
# conv2 torch.Size([1, 16, 219, 219])
# predicted: tensor([1])
# labels:    tensor([0])
# conv2 torch.Size([1, 16, 219, 219])
# predicted: tensor([0])
# labels:    tensor([1])
# conv2 torch.Size([1, 16, 219, 219])
# predicted: tensor([1])
# labels:    tensor([2])
# conv2 torch.Size([1, 16, 219, 219])
# predicted: tensor([2])
# labels:    tensor([0])
# conv2 torch.Size([1, 16, 219, 219])
# predicted: tensor([2])
# labels:    tensor([0])
# conv2 torch.Size([1, 16, 219, 219])
# predicted: tensor([0])
# labels:    tensor([0])
# conv2 torch.Size([1, 16, 219, 219])
# predicted: tensor([0])
# labels:    tensor([0])
# conv2 torch.Size([1, 16, 219, 219])
# predicted: tensor([0])
# labels:    tensor([2])
# conv2 torch.Size([1, 16, 219, 219])
# predicted: tensor([2])
# labels:    tensor([0])
# conv2 torch.Size([1, 16, 219, 219])
# predicted: tensor([0])
# labels:    tensor([1])
# conv2 torch.Size([1, 16, 219, 219])
# predicted: tensor([1])
# labels:    tensor([0])
# conv2 torch.Size([1, 16, 219, 219])
# predicted: tensor([0])
# labels:    tensor([1])
# conv2 torch.Size([1, 16, 219, 219])
# predicted: tensor([1])
# labels:    tensor([0])
# conv2 torch.Size([1, 16, 219, 219])
# predicted: tensor([0])
# labels:    tensor([2])
# conv2 torch.Size([1, 16, 219, 219])
# predicted: tensor([2])
# labels:    tensor([2])
# conv2 torch.Size([1, 16, 219, 219])
# predicted: tensor([2])
# labels:    tensor([2])
# conv2 torch.Size([1, 16, 219, 219])
# predicted: tensor([2])
# labels:    tensor([0])
# conv2 torch.Size([1, 16, 219, 219])
# predicted: tensor([0])
# labels:    tensor([2])
# conv2 torch.Size([1, 16, 219, 219])
# predicted: tensor([2])
# labels:    tensor([1])
# conv2 torch.Size([1, 16, 219, 219])
# predicted: tensor([1])
# labels:    tensor([0])
# conv2 torch.Size([1, 16, 219, 219])
# predicted: tensor([0])
# labels:    tensor([2])
# conv2 torch.Size([1, 16, 219, 219])
# predicted: tensor([2])
# labels:    tensor([0])
# conv2 torch.Size([1, 16, 219, 219])
# predicted: tensor([0])
# labels:    tensor([2])
# conv2 torch.Size([1, 16, 219, 219])
# predicted: tensor([2])
# labels:    tensor([0])
# conv2 torch.Size([1, 16, 219, 219])
# predicted: tensor([0])
# labels:    tensor([1])
# conv2 torch.Size([1, 16, 219, 219])
# predicted: tensor([1])
# labels:    tensor([2])
# conv2 torch.Size([1, 16, 219, 219])
# predicted: tensor([1])
# labels:    tensor([1])
# conv2 torch.Size([1, 16, 219, 219])
# predicted: tensor([1])
# labels:    tensor([0])
# conv2 torch.Size([1, 16, 219, 219])
# predicted: tensor([2])
# labels:    tensor([0])
# conv2 torch.Size([1, 16, 219, 219])
# predicted: tensor([0])
# labels:    tensor([2])
# conv2 torch.Size([1, 16, 219, 219])
# predicted: tensor([2])
# labels:    tensor([1])
# conv2 torch.Size([1, 16, 219, 219])
# predicted: tensor([1])
# labels:    tensor([2])
# conv2 torch.Size([1, 16, 219, 219])
# predicted: tensor([2])
# labels:    tensor([1])
# conv2 torch.Size([1, 16, 219, 219])
# predicted: tensor([1])
# labels:    tensor([0])
# conv2 torch.Size([1, 16, 219, 219])
# predicted: tensor([0])
# labels:    tensor([2])
# conv2 torch.Size([1, 16, 219, 219])
# predicted: tensor([0])
# labels:    tensor([1])
# conv2 torch.Size([1, 16, 219, 219])
# predicted: tensor([1])
# labels:    tensor([2])
# conv2 torch.Size([1, 16, 219, 219])
# predicted: tensor([1])
# labels:    tensor([0])
# conv2 torch.Size([1, 16, 219, 219])
# predicted: tensor([0])
# labels:    tensor([1])
# conv2 torch.Size([1, 16, 219, 219])
# predicted: tensor([1])
# labels:    tensor([0])
# conv2 torch.Size([1, 16, 219, 219])
# predicted: tensor([0])
# labels:    tensor([1])
# conv2 torch.Size([1, 16, 219, 219])
# predicted: tensor([1])
# labels:    tensor([1])
# conv2 torch.Size([1, 16, 219, 219])
# predicted: tensor([1])
# labels:    tensor([0])
# conv2 torch.Size([1, 16, 219, 219])
# predicted: tensor([0])
# labels:    tensor([1])
# conv2 torch.Size([1, 16, 219, 219])
# predicted: tensor([1])
# labels:    tensor([1])
# conv2 torch.Size([1, 16, 219, 219])
# predicted: tensor([1])
# labels:    tensor([0])
# conv2 torch.Size([1, 16, 219, 219])
# predicted: tensor([2])
# labels:    tensor([0])
# conv2 torch.Size([1, 16, 219, 219])
# predicted: tensor([0])
# labels:    tensor([2])
# conv2 torch.Size([1, 16, 219, 219])
# predicted: tensor([2])
# labels:    tensor([0])
# conv2 torch.Size([1, 16, 219, 219])
# predicted: tensor([0])
# labels:    tensor([1])
# conv2 torch.Size([1, 16, 219, 219])
# predicted: tensor([1])
# labels:    tensor([0])
# conv2 torch.Size([1, 16, 219, 219])
# predicted: tensor([0])
# labels:    tensor([2])
# conv2 torch.Size([1, 16, 219, 219])
# predicted: tensor([2])
# labels:    tensor([1])
# conv2 torch.Size([1, 16, 219, 219])
# predicted: tensor([1])
# labels:    tensor([0])
# conv2 torch.Size([1, 16, 219, 219])
# predicted: tensor([0])
# labels:    tensor([2])
# conv2 torch.Size([1, 16, 219, 219])
# predicted: tensor([0])
# labels:    tensor([1])
# conv2 torch.Size([1, 16, 219, 219])
# predicted: tensor([1])
# labels:    tensor([2])
# conv2 torch.Size([1, 16, 219, 219])
# predicted: tensor([2])
# labels:    tensor([0])
# conv2 torch.Size([1, 16, 219, 219])
# predicted: tensor([0])
# labels:    tensor([2])
# conv2 torch.Size([1, 16, 219, 219])
# predicted: tensor([2])
# labels:    tensor([1])
# conv2 torch.Size([1, 16, 219, 219])
# predicted: tensor([1])
# labels:    tensor([1])
# conv2 torch.Size([1, 16, 219, 219])
# predicted: tensor([1])
# labels:    tensor([2])
# conv2 torch.Size([1, 16, 219, 219])
# predicted: tensor([2])
# labels:    tensor([0])
# conv2 torch.Size([1, 16, 219, 219])
# predicted: tensor([0])
# labels:    tensor([0])
# conv2 torch.Size([1, 16, 219, 219])
# predicted: tensor([0])
# labels:    tensor([0])
# conv2 torch.Size([1, 16, 219, 219])
# predicted: tensor([0])
# labels:    tensor([0])
# conv2 torch.Size([1, 16, 219, 219])
# predicted: tensor([0])
# labels:    tensor([1])
# conv2 torch.Size([1, 16, 219, 219])
# predicted: tensor([1])
# labels:    tensor([2])
# conv2 torch.Size([1, 16, 219, 219])
# predicted: tensor([2])
# labels:    tensor([1])
# conv2 torch.Size([1, 16, 219, 219])
# predicted: tensor([1])
# labels:    tensor([0])
# conv2 torch.Size([1, 16, 219, 219])
# predicted: tensor([2])
# labels:    tensor([0])
# conv2 torch.Size([1, 16, 219, 219])
# predicted: tensor([0])
# labels:    tensor([1])
# conv2 torch.Size([1, 16, 219, 219])
# predicted: tensor([1])
# labels:    tensor([2])
# conv2 torch.Size([1, 16, 219, 219])
# predicted: tensor([0])
# labels:    tensor([1])
# conv2 torch.Size([1, 16, 219, 219])
# predicted: tensor([1])
# labels:    tensor([1])
# conv2 torch.Size([1, 16, 219, 219])
# predicted: tensor([1])
# labels:    tensor([0])
# conv2 torch.Size([1, 16, 219, 219])
# predicted: tensor([0])
# labels:    tensor([1])
# conv2 torch.Size([1, 16, 219, 219])
# predicted: tensor([1])
# labels:    tensor([0])
# conv2 torch.Size([1, 16, 219, 219])
# predicted: tensor([0])
# [1,  2000] loss: 0.670
# labels:    tensor([1])
# conv2 torch.Size([1, 16, 219, 219])
# predicted: tensor([1])
# labels:    tensor([2])
# conv2 torch.Size([1, 16, 219, 219])
# predicted: tensor([0])
# labels:    tensor([2])
# conv2 torch.Size([1, 16, 219, 219])
# predicted: tensor([1])
# labels:    tensor([1])
# conv2 torch.Size([1, 16, 219, 219])
# predicted: tensor([1])
# labels:    tensor([1])
# conv2 torch.Size([1, 16, 219, 219])
# predicted: tensor([1])
# labels:    tensor([2])
# conv2 torch.Size([1, 16, 219, 219])
# predicted: tensor([2])
# labels:    tensor([2])
# conv2 torch.Size([1, 16, 219, 219])
# predicted: tensor([0])
# labels:    tensor([1])
# conv2 torch.Size([1, 16, 219, 219])
# predicted: tensor([1])
# labels:    tensor([0])
# conv2 torch.Size([1, 16, 219, 219])
# predicted: tensor([2])
# labels:    tensor([1])
# conv2 torch.Size([1, 16, 219, 219])
# predicted: tensor([1])
# labels:    tensor([0])
# conv2 torch.Size([1, 16, 219, 219])
# predicted: tensor([0])
# labels:    tensor([0])
# conv2 torch.Size([1, 16, 219, 219])
# predicted: tensor([0])
# labels:    tensor([2])
# conv2 torch.Size([1, 16, 219, 219])
# predicted: tensor([2])
# labels:    tensor([0])
# conv2 torch.Size([1, 16, 219, 219])
# predicted: tensor([0])
# labels:    tensor([1])
# conv2 torch.Size([1, 16, 219, 219])
# predicted: tensor([1])
# labels:    tensor([1])
# conv2 torch.Size([1, 16, 219, 219])
# predicted: tensor([1])
# labels:    tensor([0])
# conv2 torch.Size([1, 16, 219, 219])
# predicted: tensor([0])
# labels:    tensor([1])
# conv2 torch.Size([1, 16, 219, 219])
# predicted: tensor([1])
# labels:    tensor([0])
# conv2 torch.Size([1, 16, 219, 219])
# predicted: tensor([0])
# labels:    tensor([2])
# conv2 torch.Size([1, 16, 219, 219])
# predicted: tensor([2])
# labels:    tensor([0])
# conv2 torch.Size([1, 16, 219, 219])
# predicted: tensor([0])
# labels:    tensor([2])
# conv2 torch.Size([1, 16, 219, 219])
# predicted: tensor([2])
# labels:    tensor([2])
# conv2 torch.Size([1, 16, 219, 219])
# predicted: tensor([2])
# labels:    tensor([0])
# conv2 torch.Size([1, 16, 219, 219])
# predicted: tensor([0])
# labels:    tensor([2])
# conv2 torch.Size([1, 16, 219, 219])
# predicted: tensor([2])
# labels:    tensor([0])
# conv2 torch.Size([1, 16, 219, 219])
# predicted: tensor([0])
# labels:    tensor([2])
# conv2 torch.Size([1, 16, 219, 219])
# predicted: tensor([2])
# labels:    tensor([2])
# conv2 torch.Size([1, 16, 219, 219])
# predicted: tensor([1])
# labels:    tensor([2])
# conv2 torch.Size([1, 16, 219, 219])
# predicted: tensor([2])
# labels:    tensor([2])
# conv2 torch.Size([1, 16, 219, 219])
# predicted: tensor([2])
# labels:    tensor([2])
# conv2 torch.Size([1, 16, 219, 219])
# predicted: tensor([2])
# labels:    tensor([2])
# ...
# predicted: tensor([0])
# labels:    tensor([2])
# conv2 torch.Size([1, 16, 219, 219])
# predicted: tensor([2])
# labels:    tensor([2])
# conv2 torch.Size([1, 16, 219, 219])
# predicted: tensor([2])
# labels:    tensor([1])
# conv2 torch.Size([1, 16, 219, 219])
# predicted: tensor([1])
# labels:    tensor([2])
# conv2 torch.Size([1, 16, 219, 219])
# predicted: tensor([2])
# labels:    tensor([1])
# conv2 torch.Size([1, 16, 219, 219])
# predicted: tensor([1])
# labels:    tensor([0])
# conv2 torch.Size([1, 16, 219, 219])
# predicted: tensor([0])
# labels:    tensor([2])
# conv2 torch.Size([1, 16, 219, 219])
# predicted: tensor([2])
# labels:    tensor([1])
# conv2 torch.Size([1, 16, 219, 219])
# predicted: tensor([1])
# labels:    tensor([0])
# conv2 torch.Size([1, 16, 219, 219])
# predicted: tensor([0])
# labels:    tensor([0])
# conv2 torch.Size([1, 16, 219, 219])
# predicted: tensor([0])
# labels:    tensor([1])
# conv2 torch.Size([1, 16, 219, 219])
# predicted: tensor([1])
# labels:    tensor([0])
# conv2 torch.Size([1, 16, 219, 219])
# predicted: tensor([2])
# labels:    tensor([0])
# conv2 torch.Size([1, 16, 219, 219])
# predicted: tensor([0])
# labels:    tensor([1])
# conv2 torch.Size([1, 16, 219, 219])
# predicted: tensor([1])
# labels:    tensor([0])
# conv2 torch.Size([1, 16, 219, 219])
# predicted: tensor([0])
# labels:    tensor([1])
# conv2 torch.Size([1, 16, 219, 219])
# predicted: tensor([1])
# labels:    tensor([0])
# conv2 torch.Size([1, 16, 219, 219])
# predicted: tensor([0])
# labels:    tensor([1])
# conv2 torch.Size([1, 16, 219, 219])
# predicted: tensor([1])
# labels:    tensor([1])
# conv2 torch.Size([1, 16, 219, 219])
# predicted: tensor([1])
# labels:    tensor([2])
# conv2 torch.Size([1, 16, 219, 219])
# predicted: tensor([2])
# labels:    tensor([0])
# conv2 torch.Size([1, 16, 219, 219])
# predicted: tensor([0])
# labels:    tensor([2])
# conv2 torch.Size([1, 16, 219, 219])
# predicted: tensor([2])
# labels:    tensor([2])
# conv2 torch.Size([1, 16, 219, 219])
# predicted: tensor([2])
# labels:    tensor([0])
# conv2 torch.Size([1, 16, 219, 219])
# predicted: tensor([0])
# labels:    tensor([0])
# conv2 torch.Size([1, 16, 219, 219])
# predicted: tensor([0])
# labels:    tensor([2])
# conv2 torch.Size([1, 16, 219, 219])
# predicted: tensor([2])
# labels:    tensor([0])
# conv2 torch.Size([1, 16, 219, 219])
# predicted: tensor([0])
# labels:    tensor([1])
# conv2 torch.Size([1, 16, 219, 219])
# predicted: tensor([1])
# labels:    tensor([0])
# conv2 torch.Size([1, 16, 219, 219])
# predicted: tensor([0])
# labels:    tensor([2])
# conv2 torch.Size([1, 16, 219, 219])
# predicted: tensor([0])
# labels:    tensor([1])
# conv2 torch.Size([1, 16, 219, 219])
# predicted: tensor([1])
# labels:    tensor([0])
# conv2 torch.Size([1, 16, 219, 219])
# predicted: tensor([0])
# labels:    tensor([0])
# conv2 torch.Size([1, 16, 219, 219])
# predicted: tensor([1])
# labels:    tensor([2])
# conv2 torch.Size([1, 16, 219, 219])
# predicted: tensor([2])
# labels:    tensor([2])
# conv2 torch.Size([1, 16, 219, 219])
# predicted: tensor([0])
# labels:    tensor([1])
# conv2 torch.Size([1, 16, 219, 219])
# predicted: tensor([1])
# labels:    tensor([1])
# conv2 torch.Size([1, 16, 219, 219])
# predicted: tensor([1])
# labels:    tensor([0])
# conv2 torch.Size([1, 16, 219, 219])
# predicted: tensor([0])
# labels:    tensor([1])
# conv2 torch.Size([1, 16, 219, 219])
# predicted: tensor([1])
# labels:    tensor([2])
# conv2 torch.Size([1, 16, 219, 219])
# predicted: tensor([2])
# labels:    tensor([1])
# conv2 torch.Size([1, 16, 219, 219])
# predicted: tensor([1])
# labels:    tensor([2])
# conv2 torch.Size([1, 16, 219, 219])
# predicted: tensor([2])
# labels:    tensor([2])
# conv2 torch.Size([1, 16, 219, 219])
# predicted: tensor([2])
# labels:    tensor([0])
# conv2 torch.Size([1, 16, 219, 219])
# predicted: tensor([0])
# labels:    tensor([0])
# conv2 torch.Size([1, 16, 219, 219])
# predicted: tensor([0])
# labels:    tensor([2])
# conv2 torch.Size([1, 16, 219, 219])
# predicted: tensor([2])
# labels:    tensor([1])
# conv2 torch.Size([1, 16, 219, 219])
# predicted: tensor([1])
# labels:    tensor([0])
# conv2 torch.Size([1, 16, 219, 219])
# predicted: tensor([0])
# labels:    tensor([2])
# conv2 torch.Size([1, 16, 219, 219])
# predicted: tensor([2])
# labels:    tensor([1])
# conv2 torch.Size([1, 16, 219, 219])
# predicted: tensor([1])
# labels:    tensor([0])
# conv2 torch.Size([1, 16, 219, 219])
# predicted: tensor([0])
# labels:    tensor([1])
# conv2 torch.Size([1, 16, 219, 219])
# predicted: tensor([1])
# labels:    tensor([1])
# conv2 torch.Size([1, 16, 219, 219])
# predicted: tensor([1])
# labels:    tensor([1])
# conv2 torch.Size([1, 16, 219, 219])
# predicted: tensor([1])
# labels:    tensor([1])
# conv2 torch.Size([1, 16, 219, 219])
# predicted: tensor([1])
# labels:    tensor([0])
# conv2 torch.Size([1, 16, 219, 219])
# predicted: tensor([0])
# labels:    tensor([1])
# conv2 torch.Size([1, 16, 219, 219])
# predicted: tensor([1])
# labels:    tensor([2])
# conv2 torch.Size([1, 16, 219, 219])
# predicted: tensor([2])
# labels:    tensor([2])
# conv2 torch.Size([1, 16, 219, 219])
# predicted: tensor([2])
# labels:    tensor([0])
# conv2 torch.Size([1, 16, 219, 219])
# predicted: tensor([0])
# labels:    tensor([0])
# conv2 torch.Size([1, 16, 219, 219])
# predicted: tensor([0])
# labels:    tensor([2])
# conv2 torch.Size([1, 16, 219, 219])
# predicted: tensor([2])
# labels:    tensor([2])
# conv2 torch.Size([1, 16, 219, 219])
# predicted: tensor([2])
# labels:    tensor([2])
# conv2 torch.Size([1, 16, 219, 219])
# predicted: tensor([2])
# labels:    tensor([2])
# conv2 torch.Size([1, 16, 219, 219])
# predicted: tensor([2])
# labels:    tensor([1])
# conv2 torch.Size([1, 16, 219, 219])
# predicted: tensor([1])
# labels:    tensor([0])
# conv2 torch.Size([1, 16, 219, 219])
# predicted: tensor([2])
# labels:    tensor([0])
# conv2 torch.Size([1, 16, 219, 219])
# predicted: tensor([0])
# labels:    tensor([0])
# conv2 torch.Size([1, 16, 219, 219])
# predicted: tensor([2])
# labels:    tensor([2])
# conv2 torch.Size([1, 16, 219, 219])
# predicted: tensor([2])
# labels:    tensor([0])
# conv2 torch.Size([1, 16, 219, 219])
# predicted: tensor([0])
# labels:    tensor([1])
# conv2 torch.Size([1, 16, 219, 219])
# predicted: tensor([1])
# labels:    tensor([0])
# conv2 torch.Size([1, 16, 219, 219])
# predicted: tensor([2])
# labels:    tensor([0])
# conv2 torch.Size([1, 16, 219, 219])
# predicted: tensor([0])
# labels:    tensor([1])
# conv2 torch.Size([1, 16, 219, 219])
# predicted: tensor([1])
# labels:    tensor([1])
# conv2 torch.Size([1, 16, 219, 219])
# predicted: tensor([1])
# labels:    tensor([1])
# conv2 torch.Size([1, 16, 219, 219])
# predicted: tensor([1])
# labels:    tensor([0])
# conv2 torch.Size([1, 16, 219, 219])
# predicted: tensor([0])
# labels:    tensor([2])
# conv2 torch.Size([1, 16, 219, 219])
# predicted: tensor([0])
# labels:    tensor([1])
# conv2 torch.Size([1, 16, 219, 219])
# predicted: tensor([1])
# labels:    tensor([0])
# conv2 torch.Size([1, 16, 219, 219])
# predicted: tensor([0])
# labels:    tensor([2])
# conv2 torch.Size([1, 16, 219, 219])
# predicted: tensor([0])
# labels:    tensor([0])
# conv2 torch.Size([1, 16, 219, 219])
# predicted: tensor([0])
# labels:    tensor([0])
# conv2 torch.Size([1, 16, 219, 219])
# predicted: tensor([0])
# labels:    tensor([0])
# conv2 torch.Size([1, 16, 219, 219])
# predicted: tensor([0])
# labels:    tensor([1])
# conv2 torch.Size([1, 16, 219, 219])
# predicted: tensor([1])
# labels:    tensor([0])
# conv2 torch.Size([1, 16, 219, 219])
# predicted: tensor([0])
# labels:    tensor([0])
# conv2 torch.Size([1, 16, 219, 219])
# predicted: tensor([0])
# labels:    tensor([0])
# conv2 torch.Size([1, 16, 219, 219])
# predicted: tensor([0])
# labels:    tensor([1])
# conv2 torch.Size([1, 16, 219, 219])
# predicted: tensor([1])
# labels:    tensor([0])
# conv2 torch.Size([1, 16, 219, 219])
# predicted: tensor([0])
# labels:    tensor([0])
# conv2 torch.Size([1, 16, 219, 219])
# predicted: tensor([0])
# labels:    tensor([2])
# conv2 torch.Size([1, 16, 219, 219])
# predicted: tensor([2])
# labels:    tensor([2])
# conv2 torch.Size([1, 16, 219, 219])
# predicted: tensor([2])
# labels:    tensor([2])
# conv2 torch.Size([1, 16, 219, 219])
# predicted: tensor([0])
# labels:    tensor([1])
# conv2 torch.Size([1, 16, 219, 219])
# predicted: tensor([1])
# labels:    tensor([1])
# conv2 torch.Size([1, 16, 219, 219])
# predicted: tensor([1])
# labels:    tensor([1])
# conv2 torch.Size([1, 16, 219, 219])
# predicted: tensor([1])
# labels:    tensor([2])
# conv2 torch.Size([1, 16, 219, 219])
# predicted: tensor([2])
# labels:    tensor([1])
# conv2 torch.Size([1, 16, 219, 219])
# predicted: tensor([1])
# labels:    tensor([1])
# conv2 torch.Size([1, 16, 219, 219])
# predicted: tensor([1])
# labels:    tensor([0])
# conv2 torch.Size([1, 16, 219, 219])
# predicted: tensor([0])
# labels:    tensor([2])
# conv2 torch.Size([1, 16, 219, 219])
# predicted: tensor([2])
# labels:    tensor([2])
# conv2 torch.Size([1, 16, 219, 219])
# predicted: tensor([2])
# labels:    tensor([0])
# conv2 torch.Size([1, 16, 219, 219])
# predicted: tensor([0])
# labels:    tensor([2])
# conv2 torch.Size([1, 16, 219, 219])
# predicted: tensor([0])
# labels:    tensor([1])
# conv2 torch.Size([1, 16, 219, 219])
# predicted: tensor([1])
# labels:    tensor([2])
# conv2 torch.Size([1, 16, 219, 219])
# predicted: tensor([2])
# labels:    tensor([1])
# conv2 torch.Size([1, 16, 219, 219])
# predicted: tensor([1])
# labels:    tensor([0])
# conv2 torch.Size([1, 16, 219, 219])
# predicted: tensor([0])
# labels:    tensor([1])
# conv2 torch.Size([1, 16, 219, 219])
# predicted: tensor([1])
# labels:    tensor([1])
# conv2 torch.Size([1, 16, 219, 219])
# predicted: tensor([1])
# labels:    tensor([1])
# conv2 torch.Size([1, 16, 219, 219])
# predicted: tensor([1])
# labels:    tensor([0])
# conv2 torch.Size([1, 16, 219, 219])
# predicted: tensor([0])
# labels:    tensor([1])
# conv2 torch.Size([1, 16, 219, 219])
# predicted: tensor([1])
# labels:    tensor([2])
# conv2 torch.Size([1, 16, 219, 219])
# predicted: tensor([2])
# labels:    tensor([2])
# conv2 torch.Size([1, 16, 219, 219])
# predicted: tensor([2])
# labels:    tensor([2])
# conv2 torch.Size([1, 16, 219, 219])
# predicted: tensor([2])
# labels:    tensor([1])
# conv2 torch.Size([1, 16, 219, 219])
# predicted: tensor([1])
# labels:    tensor([2])
# conv2 torch.Size([1, 16, 219, 219])
# predicted: tensor([2])
# labels:    tensor([2])
# conv2 torch.Size([1, 16, 219, 219])
# predicted: tensor([2])
# labels:    tensor([1])
# conv2 torch.Size([1, 16, 219, 219])
# predicted: tensor([1])
# labels:    tensor([2])
# conv2 torch.Size([1, 16, 219, 219])
# predicted: tensor([2])
# labels:    tensor([2])
# conv2 torch.Size([1, 16, 219, 219])
# predicted: tensor([2])
# labels:    tensor([1])
# conv2 torch.Size([1, 16, 219, 219])
# predicted: tensor([1])
# labels:    tensor([1])
# conv2 torch.Size([1, 16, 219, 219])
# predicted: tensor([1])
# labels:    tensor([0])
# conv2 torch.Size([1, 16, 219, 219])
# predicted: tensor([0])
# labels:    tensor([1])
# conv2 torch.Size([1, 16, 219, 219])
# predicted: tensor([1])
# labels:    tensor([2])
# conv2 torch.Size([1, 16, 219, 219])
# predicted: tensor([2])
# labels:    tensor([2])
# conv2 torch.Size([1, 16, 219, 219])
# predicted: tensor([2])
# labels:    tensor([0])
# conv2 torch.Size([1, 16, 219, 219])
# predicted: tensor([0])
# labels:    tensor([0])
# conv2 torch.Size([1, 16, 219, 219])
# predicted: tensor([0])
# labels:    tensor([0])
# conv2 torch.Size([1, 16, 219, 219])
# predicted: tensor([0])
# labels:    tensor([2])
# conv2 torch.Size([1, 16, 219, 219])
# predicted: tensor([2])
# labels:    tensor([0])
# conv2 torch.Size([1, 16, 219, 219])
# predicted: tensor([0])
# labels:    tensor([1])
# conv2 torch.Size([1, 16, 219, 219])
# predicted: tensor([1])
# labels:    tensor([0])
# conv2 torch.Size([1, 16, 219, 219])
# predicted: tensor([0])
# labels:    tensor([0])
# conv2 torch.Size([1, 16, 219, 219])
# predicted: tensor([0])
# labels:    tensor([2])
# conv2 torch.Size([1, 16, 219, 219])
# predicted: tensor([2])
# labels:    tensor([2])
# conv2 torch.Size([1, 16, 219, 219])
# predicted: tensor([2])
# labels:    tensor([2])
# conv2 torch.Size([1, 16, 219, 219])
# predicted: tensor([2])
# labels:    tensor([0])
# conv2 torch.Size([1, 16, 219, 219])
# predicted: tensor([0])
# labels:    tensor([0])
# conv2 torch.Size([1, 16, 219, 219])
# predicted: tensor([0])
# labels:    tensor([1])
# conv2 torch.Size([1, 16, 219, 219])
# predicted: tensor([1])
# labels:    tensor([0])
# conv2 torch.Size([1, 16, 219, 219])
# predicted: tensor([0])
# labels:    tensor([0])
# conv2 torch.Size([1, 16, 219, 219])
# predicted: tensor([0])
# labels:    tensor([1])
# conv2 torch.Size([1, 16, 219, 219])
# predicted: tensor([1])
# labels:    tensor([1])
# conv2 torch.Size([1, 16, 219, 219])
# predicted: tensor([1])
# labels:    tensor([0])
# conv2 torch.Size([1, 16, 219, 219])
# predicted: tensor([0])
# labels:    tensor([2])
# conv2 torch.Size([1, 16, 219, 219])
# predicted: tensor([2])
# labels:    tensor([2])
# conv2 torch.Size([1, 16, 219, 219])
# predicted: tensor([2])
# labels:    tensor([0])
# conv2 torch.Size([1, 16, 219, 219])
# predicted: tensor([0])
# labels:    tensor([2])
# conv2 torch.Size([1, 16, 219, 219])
# predicted: tensor([2])
# labels:    tensor([0])
# conv2 torch.Size([1, 16, 219, 219])
# predicted: tensor([0])
# labels:    tensor([0])
# conv2 torch.Size([1, 16, 219, 219])
# predicted: tensor([0])
# labels:    tensor([2])
# conv2 torch.Size([1, 16, 219, 219])
# predicted: tensor([2])
# labels:    tensor([0])
# conv2 torch.Size([1, 16, 219, 219])
# predicted: tensor([0])
# labels:    tensor([2])
# conv2 torch.Size([1, 16, 219, 219])
# predicted: tensor([2])
# labels:    tensor([1])
# conv2 torch.Size([1, 16, 219, 219])
# predicted: tensor([1])
# labels:    tensor([0])
# conv2 torch.Size([1, 16, 219, 219])
# predicted: tensor([0])
# labels:    tensor([2])
# conv2 torch.Size([1, 16, 219, 219])
# predicted: tensor([2])
# labels:    tensor([2])
# conv2 torch.Size([1, 16, 219, 219])
# predicted: tensor([1])
# labels:    tensor([2])
# conv2 torch.Size([1, 16, 219, 219])
# predicted: tensor([2])
# labels:    tensor([2])
# conv2 torch.Size([1, 16, 219, 219])
# predicted: tensor([2])
# labels:    tensor([0])
# conv2 torch.Size([1, 16, 219, 219])
# predicted: tensor([2])
# labels:    tensor([0])
# conv2 torch.Size([1, 16, 219, 219])
# predicted: tensor([0])
# labels:    tensor([1])
# conv2 torch.Size([1, 16, 219, 219])
# predicted: tensor([1])
# labels:    tensor([2])
# conv2 torch.Size([1, 16, 219, 219])
# predicted: tensor([2])
# labels:    tensor([0])
# conv2 torch.Size([1, 16, 219, 219])
# predicted: tensor([2])
# labels:    tensor([0])
# conv2 torch.Size([1, 16, 219, 219])
# predicted: tensor([0])
# labels:    tensor([2])
# conv2 torch.Size([1, 16, 219, 219])
# predicted: tensor([2])
# labels:    tensor([0])
# conv2 torch.Size([1, 16, 219, 219])
# predicted: tensor([2])
# labels:    tensor([1])
# conv2 torch.Size([1, 16, 219, 219])
# predicted: tensor([1])
# labels:    tensor([2])
# conv2 torch.Size([1, 16, 219, 219])
# predicted: tensor([2])
# labels:    tensor([0])
# conv2 torch.Size([1, 16, 219, 219])
# predicted: tensor([0])
# labels:    tensor([1])
# conv2 torch.Size([1, 16, 219, 219])
# predicted: tensor([1])
# labels:    tensor([1])
# conv2 torch.Size([1, 16, 219, 219])
# predicted: tensor([1])
# labels:    tensor([2])
# conv2 torch.Size([1, 16, 219, 219])
# predicted: tensor([2])
# labels:    tensor([0])
# conv2 torch.Size([1, 16, 219, 219])
# predicted: tensor([0])
# labels:    tensor([0])
# conv2 torch.Size([1, 16, 219, 219])
# predicted: tensor([0])
# labels:    tensor([2])
# conv2 torch.Size([1, 16, 219, 219])
# predicted: tensor([2])
# labels:    tensor([0])
# conv2 torch.Size([1, 16, 219, 219])
# predicted: tensor([0])
# labels:    tensor([2])
# conv2 torch.Size([1, 16, 219, 219])
# predicted: tensor([0])
# labels:    tensor([0])
# conv2 torch.Size([1, 16, 219, 219])
# predicted: tensor([2])
# labels:    tensor([2])
# conv2 torch.Size([1, 16, 219, 219])
# predicted: tensor([2])
# labels:    tensor([0])
# conv2 torch.Size([1, 16, 219, 219])
# predicted: tensor([0])
# labels:    tensor([2])
# conv2 torch.Size([1, 16, 219, 219])
# predicted: tensor([0])
# labels:    tensor([1])
# conv2 torch.Size([1, 16, 219, 219])
# predicted: tensor([1])
# labels:    tensor([1])
# conv2 torch.Size([1, 16, 219, 219])
# predicted: tensor([1])
# labels:    tensor([1])
# conv2 torch.Size([1, 16, 219, 219])
# predicted: tensor([1])
# labels:    tensor([1])
# conv2 torch.Size([1, 16, 219, 219])
# predicted: tensor([1])
# labels:    tensor([2])
# conv2 torch.Size([1, 16, 219, 219])
# predicted: tensor([2])
# labels:    tensor([1])
# conv2 torch.Size([1, 16, 219, 219])
# predicted: tensor([1])
# Accuracy of the network on the 100(0) training images: 74 %
# Finished Training [74.13239074550128]
# time: 2h 6min 45s

# %%
print(pred)
print(actuals)
# Out:
# [tensor([0]), tensor([2]), tensor([2]), tensor([2]), tensor([2]), tensor([2]), tensor([0]), tensor([0]), tensor([0]), tensor([0]), tensor([0]), tensor([0]), tensor([0]), tensor([0]), tensor([1]), tensor([1]), tensor([1]), tensor([1]), tensor([1]), tensor([2]), tensor([2]), tensor([2]), tensor([2]), tensor([2]), tensor([0]), tensor([0]), tensor([0]), tensor([0]), tensor([0]), tensor([0]), tensor([2]), tensor([0]), tensor([0]), tensor([2]), tensor([0]), tensor([2]), tensor([2]), tensor([0]), tensor([2]), tensor([2]), tensor([2]), tensor([2]), tensor([2]), tensor([2]), tensor([2]), tensor([2]), tensor([2]), tensor([2]), tensor([0]), tensor([2]), tensor([0]), tensor([0]), tensor([0]), tensor([0]), tensor([0]), tensor([0]), tensor([0]), tensor([0]), tensor([0]), tensor([0]), tensor([0]), tensor([0]), tensor([0]), tensor([0]), tensor([2]), tensor([0]), tensor([2]), tensor([2]), tensor([2]), tensor([2]), tensor([2]), tensor([2]), tensor([2]), tensor([2]), tensor([2]), tensor([2]), tensor([2]), tensor([2]), tensor([2]), tensor([2]), tensor([2]), tensor([2]), tensor([2]), tensor([2]), tensor([0]), tensor([0]), tensor([0]), tensor([0]), tensor([2]), tensor([0]), tensor([2]), tensor([0]), tensor([0]), tensor([0]), tensor([0]), tensor([0]), tensor([0]), tensor([0]), tensor([0]), tensor([0]), tensor([0]), tensor([0]), tensor([0]), tensor([0]), tensor([0]), tensor([0]), tensor([0]), tensor([0]), tensor([0]), tensor([0]), tensor([2]), tensor([0]), tensor([0]), tensor([0]), tensor([0]), tensor([2]), tensor([0]), tensor([0]), tensor([2]), tensor([2]), tensor([2]), tensor([2]), tensor([0]), tensor([2]), tensor([2]), tensor([2]), tensor([2]), tensor([0]), tensor([2]), tensor([2]), tensor([2]), tensor([2]), tensor([2]), tensor([2]), tensor([2]), tensor([0]), tensor([2]), tensor([0]), tensor([2]), tensor([0]), tensor([0]), tensor([2]), tensor([0]), tensor([0]), tensor([0]), tensor([0]), tensor([0]), tensor([2]), tensor([2]), tensor([2]), tensor([2]), tensor([2]), tensor([0]), tensor([2]), tensor([2]), tensor([2]), tensor([2]), tensor([2]), tensor([2]), tensor([2]), tensor([2]), tensor([2]), tensor([2]), tensor([2]), tensor([2]), tensor([2]), tensor([2]), tensor([2]), tensor([2]), tensor([2]), tensor([2]), tensor([2]), tensor([0]), tensor([0]), tensor([2]), tensor([2]), tensor([0]), tensor([2]), tensor([2]), tensor([2]), tensor([0]), tensor([0]), tensor([2]), tensor([0]), tensor([0]), tensor([0]), tensor([2]), tensor([2]), tensor([2]), tensor([2]), tensor([0]), tensor([2]), tensor([2]), tensor([2]), tensor([2]), tensor([2]), tensor([2]), tensor([2]), tensor([2]), tensor([2]), tensor([2]), tensor([2]), tensor([2]), tensor([2]), tensor([2]), tensor([2]), tensor([2]), tensor([2]), tensor([2]), tensor([2]), tensor([2]), tensor([0]), tensor([2]), tensor([2]), tensor([0]), tensor([2]), tensor([2]), tensor([2]), tensor([0]), tensor([2]), tensor([0]), tensor([2]), tensor([2]), tensor([2]), tensor([2]), tensor([0]), tensor([0]), tensor([0]), tensor([0]), tensor([0]), tensor([0]), tensor([0]), tensor([0]), tensor([0]), tensor([2]), tensor([2]), tensor([2]), tensor([2]), tensor([2]), tensor([2]), tensor([2]), tensor([2]), tensor([2]), tensor([2]), tensor([2]), tensor([2]), tensor([2]), tensor([2]), tensor([2]), tensor([2]), tensor([0]), tensor([2]), tensor([2]), tensor([0]), tensor([0]), tensor([0]), tensor([0]), tensor([0]), tensor([0]), tensor([0]), tensor([2]), tensor([2]), tensor([2]), tensor([0]), tensor([2]), tensor([2]), tensor([2]), tensor([2]), tensor([2]), tensor([2]), tensor([2]), tensor([2]), tensor([2]), tensor([2]), tensor([2]), tensor([2]), tensor([2]), tensor([2]), tensor([2]), tensor([2]), tensor([2]), tensor([2]), tensor([2]), tensor([2]), tensor([0]), tensor([0]), tensor([2]), tensor([0]), tensor([2]), tensor([2]), tensor([0]), tensor([2]), tensor([2]), tensor([2]), tensor([0]), tensor([2]), tensor([0]), tensor([0]), tensor([0]), tensor([2]), tensor([2]), tensor([2]), tensor([0]), tensor([2]), tensor([2]), tensor([2]), tensor([0]), tensor([ ...
# [tensor([2]), tensor([2]), tensor([2]), tensor([1]), tensor([0]), tensor([0]), tensor([1]), tensor([0]), tensor([0]), tensor([0]), tensor([2]), tensor([0]), tensor([1]), tensor([2]), tensor([2]), tensor([1]), tensor([2]), tensor([0]), tensor([2]), tensor([1]), tensor([0]), tensor([2]), tensor([2]), tensor([0]), tensor([0]), tensor([2]), tensor([0]), tensor([2]), tensor([2]), tensor([0]), tensor([1]), tensor([0]), tensor([2]), tensor([1]), tensor([0]), tensor([1]), tensor([2]), tensor([2]), tensor([2]), tensor([0]), tensor([0]), tensor([2]), tensor([2]), tensor([0]), tensor([2]), tensor([2]), tensor([2]), tensor([0]), tensor([0]), tensor([0]), tensor([0]), tensor([2]), tensor([1]), tensor([0]), tensor([0]), tensor([0]), tensor([1]), tensor([1]), tensor([0]), tensor([1]), tensor([0]), tensor([1]), tensor([1]), tensor([2]), tensor([1]), tensor([2]), tensor([2]), tensor([0]), tensor([1]), tensor([2]), tensor([2]), tensor([0]), tensor([1]), tensor([0]), tensor([1]), tensor([0]), tensor([2]), tensor([2]), tensor([0]), tensor([2]), tensor([1]), tensor([2]), tensor([0]), tensor([1]), tensor([0]), tensor([2]), tensor([0]), tensor([2]), tensor([1]), tensor([0]), tensor([0]), tensor([0]), tensor([0]), tensor([0]), tensor([0]), tensor([0]), tensor([0]), tensor([1]), tensor([0]), tensor([1]), tensor([2]), tensor([2]), tensor([0]), tensor([1]), tensor([2]), tensor([1]), tensor([0]), tensor([2]), tensor([0]), tensor([0]), tensor([1]), tensor([0]), tensor([2]), tensor([2]), tensor([0]), tensor([1]), tensor([2]), tensor([0]), tensor([2]), tensor([2]), tensor([1]), tensor([1]), tensor([2]), tensor([1]), tensor([0]), tensor([2]), tensor([1]), tensor([2]), tensor([0]), tensor([0]), tensor([1]), tensor([0]), tensor([0]), tensor([0]), tensor([2]), tensor([2]), tensor([1]), tensor([0]), tensor([1]), tensor([2]), tensor([2]), tensor([2]), tensor([2]), tensor([0]), tensor([2]), tensor([0]), tensor([2]), tensor([1]), tensor([1]), tensor([2]), tensor([2]), tensor([1]), tensor([0]), tensor([2]), tensor([0]), tensor([1]), tensor([0]), tensor([1]), tensor([1]), tensor([1]), tensor([1]), tensor([2]), tensor([1]), tensor([1]), tensor([2]), tensor([0]), tensor([2]), tensor([2]), tensor([0]), tensor([1]), tensor([0]), tensor([1]), tensor([0]), tensor([1]), tensor([1]), tensor([2]), tensor([0]), tensor([2]), tensor([1]), tensor([2]), tensor([0]), tensor([0]), tensor([1]), tensor([2]), tensor([0]), tensor([2]), tensor([1]), tensor([1]), tensor([1]), tensor([2]), tensor([2]), tensor([1]), tensor([2]), tensor([0]), tensor([0]), tensor([0]), tensor([1]), tensor([1]), tensor([2]), tensor([1]), tensor([0]), tensor([1]), tensor([1]), tensor([1]), tensor([1]), tensor([0]), tensor([1]), tensor([0]), tensor([2]), tensor([1]), tensor([1]), tensor([2]), tensor([0]), tensor([1]), tensor([0]), tensor([1]), tensor([1]), tensor([1]), tensor([0]), tensor([0]), tensor([2]), tensor([1]), tensor([1]), tensor([0]), tensor([1]), tensor([2]), tensor([0]), tensor([2]), tensor([2]), tensor([0]), tensor([2]), tensor([2]), tensor([2]), tensor([2]), tensor([1]), tensor([2]), tensor([2]), tensor([0]), tensor([1]), tensor([2]), tensor([0]), tensor([2]), tensor([2]), tensor([0]), tensor([0]), tensor([1]), tensor([2]), tensor([1]), tensor([0]), tensor([2]), tensor([0]), tensor([2]), tensor([0]), tensor([0]), tensor([0]), tensor([2]), tensor([2]), tensor([0]), tensor([2]), tensor([2]), tensor([1]), tensor([1]), tensor([1]), tensor([2]), tensor([2]), tensor([1]), tensor([2]), tensor([2]), tensor([2]), tensor([2]), tensor([1]), tensor([2]), tensor([2]), tensor([0]), tensor([0]), tensor([1]), tensor([2]), tensor([2]), tensor([0]), tensor([2]), tensor([1]), tensor([1]), tensor([2]), tensor([1]), tensor([0]), tensor([0]), tensor([1]), tensor([2]), tensor([2]), tensor([1]), tensor([0]), tensor([1]), tensor([1]), tensor([1]), tensor([2]), tensor([1]), tensor([0]), tensor([0]), tensor([2]), tensor([2]), tensor([0]), tensor([1]), tensor([2]), tensor([2]), tensor([1]), tensor([0]), tensor([2]), tensor([ ...
# time: 187 ms

# %%
torch.save({
            # 'epoch': epochs,
            'net_state_dict': net.state_dict(),
            'optimizer_state_dict': optimizer.state_dict(),
            'loss': loss,
            }, '/content/NCA92%filt2000.tar')
# Out:
# time: 3.03 s

# %%
# import matlab.engine
# import filt

# myfilter = filt.initialize()
# img =  Image.open('/content/C_119_left - Copy (4).jpg').convert('RGB')
# out = myfilter.filt(img)

# myfilter.terminate()
# Out:
# time: 997 µs

# %%
correct = 0
total = 0
with torch.no_grad():
    for data in testloader:
        images, labels = data
        outputs = net(images)
        _, predicted = torch.max(outputs.data, 1)
        total += labels.size(0)
        correct += (predicted == labels).sum().item()

print('Accuracy of the network on the 10000 test images: %d %%' % (
    100 * correct / total))
# Out:
# conv2 torch.Size([4, 16, 219, 219])
# conv2 torch.Size([4, 16, 219, 219])
# conv2 torch.Size([4, 16, 219, 219])
# conv2 torch.Size([4, 16, 219, 219])
# conv2 torch.Size([4, 16, 219, 219])
# conv2 torch.Size([4, 16, 219, 219])
# conv2 torch.Size([4, 16, 219, 219])
# conv2 torch.Size([4, 16, 219, 219])
# conv2 torch.Size([4, 16, 219, 219])
# conv2 torch.Size([4, 16, 219, 219])
# conv2 torch.Size([4, 16, 219, 219])
# conv2 torch.Size([4, 16, 219, 219])
# conv2 torch.Size([4, 16, 219, 219])
# conv2 torch.Size([4, 16, 219, 219])
# conv2 torch.Size([4, 16, 219, 219])
# conv2 torch.Size([4, 16, 219, 219])
# conv2 torch.Size([4, 16, 219, 219])
# conv2 torch.Size([4, 16, 219, 219])
# conv2 torch.Size([4, 16, 219, 219])
# conv2 torch.Size([4, 16, 219, 219])
# conv2 torch.Size([4, 16, 219, 219])
# conv2 torch.Size([4, 16, 219, 219])
# conv2 torch.Size([4, 16, 219, 219])
# conv2 torch.Size([4, 16, 219, 219])
# conv2 torch.Size([4, 16, 219, 219])
# conv2 torch.Size([4, 16, 219, 219])
# conv2 torch.Size([4, 16, 219, 219])
# conv2 torch.Size([4, 16, 219, 219])
# conv2 torch.Size([4, 16, 219, 219])
# conv2 torch.Size([4, 16, 219, 219])
# conv2 torch.Size([4, 16, 219, 219])
# conv2 torch.Size([4, 16, 219, 219])
# conv2 torch.Size([4, 16, 219, 219])
# conv2 torch.Size([4, 16, 219, 219])
# conv2 torch.Size([4, 16, 219, 219])
# conv2 torch.Size([4, 16, 219, 219])
# conv2 torch.Size([4, 16, 219, 219])
# conv2 torch.Size([4, 16, 219, 219])
# conv2 torch.Size([4, 16, 219, 219])
# conv2 torch.Size([4, 16, 219, 219])
# conv2 torch.Size([4, 16, 219, 219])
# conv2 torch.Size([4, 16, 219, 219])
# conv2 torch.Size([4, 16, 219, 219])
# conv2 torch.Size([4, 16, 219, 219])
# conv2 torch.Size([4, 16, 219, 219])
# conv2 torch.Size([4, 16, 219, 219])
# conv2 torch.Size([4, 16, 219, 219])
# conv2 torch.Size([4, 16, 219, 219])
# conv2 torch.Size([4, 16, 219, 219])
# conv2 torch.Size([4, 16, 219, 219])
# conv2 torch.Size([4, 16, 219, 219])
# conv2 torch.Size([4, 16, 219, 219])
# conv2 torch.Size([4, 16, 219, 219])
# conv2 torch.Size([4, 16, 219, 219])
# conv2 torch.Size([4, 16, 219, 219])
# conv2 torch.Size([4, 16, 219, 219])
# conv2 torch.Size([4, 16, 219, 219])
# conv2 torch.Size([4, 16, 219, 219])
# conv2 torch.Size([4, 16, 219, 219])
# conv2 torch.Size([4, 16, 219, 219])
# conv2 torch.Size([4, 16, 219, 219])
# conv2 torch.Size([4, 16, 219, 219])
# conv2 torch.Size([4, 16, 219, 219])
# conv2 torch.Size([4, 16, 219, 219])
# conv2 torch.Size([4, 16, 219, 219])
# conv2 torch.Size([4, 16, 219, 219])
# conv2 torch.Size([4, 16, 219, 219])
# conv2 torch.Size([4, 16, 219, 219])
# conv2 torch.Size([4, 16, 219, 219])
# conv2 torch.Size([4, 16, 219, 219])
# conv2 torch.Size([4, 16, 219, 219])
# conv2 torch.Size([4, 16, 219, 219])
# conv2 torch.Size([4, 16, 219, 219])
# conv2 torch.Size([4, 16, 219, 219])
# conv2 torch.Size([4, 16, 219, 219])
# conv2 torch.Size([4, 16, 219, 219])
# conv2 torch.Size([4, 16, 219, 219])
# conv2 torch.Size([4, 16, 219, 219])
# conv2 torch.Size([4, 16, 219, 219])
# conv2 torch.Size([4, 16, 219, 219])
# conv2 torch.Size([4, 16, 219, 219])
# conv2 torch.Size([4, 16, 219, 219])
# conv2 torch.Size([4, 16, 219, 219])
# conv2 torch.Size([4, 16, 219, 219])
# conv2 torch.Size([4, 16, 219, 219])
# conv2 torch.Size([4, 16, 219, 219])
# conv2 torch.Size([4, 16, 219, 219])
# conv2 torch.Size([4, 16, 219, 219])
# conv2 torch.Size([4, 16, 219, 219])
# conv2 torch.Size([4, 16, 219, 219])
# conv2 torch.Size([4, 16, 219, 219])
# conv2 torch.Size([4, 16, 219, 219])
# conv2 torch.Size([4, 16, 219, 219])
# conv2 torch.Size([4, 16, 219, 219])
# conv2 torch.Size([4, 16, 219, 219])
# conv2 torch.Size([4, 16, 219, 219])
# conv2 torch.Size([4, 16, 219, 219])
# conv2 torch.Size([3, 16, 219, 219])
# Accuracy of the network on the 10000 test images: 92 %
# time: 2min 43s
